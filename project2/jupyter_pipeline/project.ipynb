# %% [markdown]
# # Deploy and monitor a machine learning workflow for Image Classification

# %% [markdown]
# Reference:https://sagemaker.readthedocs.io/en/stable/index.html

# %% [markdown]
# ## Data Staging
#
# We'll use a sample dataset called CIFAR to simulate the challenges Scones Unlimited are facing in Image Classification. In order to start working with CIFAR we'll need to:
#
# 1. Extract the data from a hosting service
# 2. Transform it into a usable shape and format
# 3. Load it into a production system
#
# In other words, we're going to do some simple ETL!
#
# ### 1. Extract the data from the hosting service
#
# In the cell below, define a function `extract_cifar_data` that extracts python version of the CIFAR-100 dataset. The CIFAR dataaset is open source and generously hosted by the University of Toronto at: https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz

# %%
# !pip install pandarallel

# %%
import os
import time

import requests
import tqdm


def extract_cifar_data(url, filename="cifar.tar.gz"):
    """A function for extracting the CIFAR-100 dataset and storing it as a gzipped file
    
    Arguments:
    url      -- the URL where the dataset is hosted
    filename -- the full path where the dataset will be written
    
    """
###### Method 1 ######
#     r = requests.get(url)
#     with open(filename, "wb") as file_context:
#         file_context.write(r.content)
#     return

###### Method 2 ######
    try:
        response = requests.get(url, stream=True)
        assert response.status_code == 200
    except Exception:
        raise
    else:
        file = os.path.join(save_loc, filename)
        with tqdm.wrapattr(
            open(file, 'wb'), 'write',
            unit='B', unit_scale=True, unit_divisor=1024, mniters=1,
            desc=filename, total=int(response.headers.get('content-length', 0))
        ) as fout:
            for chunk in response.iter_content(chunk_size=4096):
                fout.write(chunk)

# %% [markdown]
# Let's test it out! Run the following cell and check whether a new file `cifar.tar.gz` is created in the file explorer.

# %%
extract_cifar_data("https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz")

# %% [markdown]
# ### 2. Transform the data into a usable shape and format
#
# Clearly, distributing the data as a gzipped archive makes sense for the hosting service! It saves on bandwidth, storage, and it's a widely-used archive format. In fact, it's so widely used that the Python community ships a utility for working with them, `tarfile`, as part of its Standard Library. Execute the following cell to decompress your extracted dataset:

# %%
import tarfile

with tarfile.open("cifar.tar.gz", "r:gz") as tar:
    tar.extractall()

# %% [markdown]
# A new folder `cifar-100-python` should be created, containing `meta`, `test`, and `train` files. These files are `pickles` and the [CIFAR homepage](https://www.cs.toronto.edu/~kriz/cifar.html) provides a simple script that can be used to load them. We've adapted the script below for you to run:

# %%
import pickle

with open("./cifar-100-python/meta", "rb") as f:
    dataset_meta = pickle.load(f, encoding='bytes')

with open("./cifar-100-python/test", "rb") as f:
    dataset_test = pickle.load(f, encoding='bytes')

with open("./cifar-100-python/train", "rb") as f:
    dataset_train = pickle.load(f, encoding='bytes')

# %%
# Feel free to explore the datasets

dataset_train.keys()
# Out:
# dict_keys([b'filenames', b'batch_label', b'fine_labels', b'coarse_labels', b'data'])

# %% [markdown]
# As documented on the homepage, `b'data'` contains rows of 3073 unsigned integers, representing three channels (red, green, and blue) for one 32x32 pixel image per row.

# %%
32*32*3
# Out:
# 3072

# %% [markdown]
# For a simple gut-check, let's transform one of our images. Each 1024 items in a row is a channel (red, green, then blue). Each 32 items in the channel are a row in the 32x32 image. Using python, we can stack these channels into a 32x32x3 array, and save it as a PNG file:

# %%
import numpy as np

# Each 1024 in a row is a channel (red, green, then blue)
row = dataset_train[b'data'][0]
red, green, blue = row[0:1024], row[1024:2048], row[2048:]

# Each 32 items in the channel are a row in the 32x32 image
red = red.reshape(32,32)
green = green.reshape(32,32)
blue = blue.reshape(32,32)

# Combine the channels into a 32x32x3 image!
combined = np.dstack((red,green,blue))

# %% [markdown]
# For a more concise version, consider the following:

# %%
# All in one:
test_image = np.dstack((
    row[0:1024].reshape(32,32),
    row[1024:2048].reshape(32,32),
    row[2048:].reshape(32,32)
))

# %%
import matplotlib.pyplot as plt
plt.imshow(test_image);

# %% [markdown]
# Looks like a cow! Let's check the label. `dataset_meta` contains label names in order, and `dataset_train` has a list of labels for each row.

# %%
dataset_train[b'fine_labels'][0]
# Out:
# 19

# %% [markdown]
# Our image has a label of `19`, so let's see what the 19th item is in the list of label names.

# %%
print(dataset_meta[b'fine_label_names'][19])
# Out:
# b'cattle'

# %% [markdown]
# Ok! 'cattle' sounds about right. By the way, using the previous two lines we can do:

# %%
n = 0
print(dataset_meta[b'fine_label_names'][dataset_train[b'fine_labels'][n]])
# Out:
# b'cattle'

# %% [markdown]
# Now we know how to check labels, is there a way that we can also check file names? `dataset_train` also contains a `b'filenames'` key. Let's see what we have here:

# %%
print(dataset_train[b'filenames'][0])
# Out:
# b'bos_taurus_s_000507.png'

# %% [markdown]
# "Taurus" is the name of a subspecies of cattle, so this looks like a pretty reasonable filename. To save an image we can also do:

# %%
plt.imsave("file.png", test_image)

# %% [markdown]
# Your new PNG file should now appear in the file explorer -- go ahead and pop it open to see!
#
# Now that you know how to reshape the images, save them as files, and capture their filenames and labels, let's just capture all the bicycles and motorcycles and save them. Scones Unlimited can use a model that tells these apart to route delivery drivers automatically.
#
# In the following cell, identify the label numbers for Bicycles and Motorcycles:

# %%
import pandas as pd

# Filter the dataset_train and dataset_meta objects to find the label numbers for Bicycle and Motorcycles
set([label_num for label_num in dataset_train[b'fine_labels'] if dataset_meta[b'fine_label_names'][label_num] in [b'bicycle', b'motorcycle']])
# Out:
# {8, 48}

# %% [markdown]
# Good job! We only need objects with label 8 and 48 -- this drastically simplifies our handling of the data! Below we construct a dataframe for you, and you can safely drop the rows that don't contain observations about bicycles and motorcycles. Fill in the missing lines below to drop all other rows:

# %%
#Construct the dataframe
df_train = pd.DataFrame({
    "filenames": dataset_train[b'filenames'],
    "labels": dataset_train[b'fine_labels'],
    "row": range(len(dataset_train[b'filenames']))
})

# # Drop all rows from df_train where label is not 8 or 48
df_train = df_train[df_train.labels.isin([8, 48])]

# Decode df_train.filenames so they are regular strings
df_train["filenames"] = df_train["filenames"].apply(
    lambda x: x.decode("utf-8")
)


df_test = pd.DataFrame({
    "filenames": dataset_test[b'filenames'],
    "labels": dataset_test[b'fine_labels'],
    "row": range(len(dataset_test[b'filenames']))
})

# Drop all rows from df_test where label is not 8 or 48
df_test = df_test[df_test.labels.isin([8, 48])]

# Decode df_test.filenames so they are regular strings
df_test["filenames"] = df_test["filenames"].apply(
    lambda x: x.decode("utf-8")
)

# %%
df_test
# Out:
#                           filenames  labels   row
# 27         safety_bike_s_000390.png       8    27
# 28                bike_s_000658.png       8    28
# 116         velocipede_s_001744.png       8   116
# 161               bike_s_000643.png       8   161
# 319   ordinary_bicycle_s_000437.png       8   319
# ...                             ...     ...   ...
# 9654        trail_bike_s_000073.png      48  9654
# 9692              bike_s_000941.png       8  9692
# 9833        motorcycle_s_000141.png      48  9833
# 9928  ordinary_bicycle_s_000105.png       8  9928
# 9939           bicycle_s_001218.png       8  9939
#
# [200 rows x 3 columns]

# %% [markdown]
# Now that the data is filtered for just our classes, we can save all our images.

# %%
# !mkdir ./train
# !mkdir ./test

# %% [markdown]
# In the previous sections we introduced you to several key snippets of code:
#
# 1. Grabbing the image data:
#
# ```python
# dataset_train[b'data'][0]
# ```
#
# 2. A simple idiom for stacking the image data into the right shape
#
# ```python
# import numpy as np
# np.dstack((
#     row[0:1024].reshape(32,32),
#     row[1024:2048].reshape(32,32),
#     row[2048:].reshape(32,32)
# ))
# ```
#
# 3. A simple `matplotlib` utility for saving images
#
# ```python
# plt.imsave(path+row['filenames'], target)
# ```
#
# Compose these together into a function that saves all the images into the `./test` and `./train` directories. Use the comments in the body of the `save_images` function below to guide your construction of the function:

# %%
# ## Method 1
# def save_images(dataset, root_dir, original_data):
#     #Grab the image data in row-major form
#     for i in range(len(dataset)):
        
#         row = dataset['row'].iloc[i]
        
#         filename = dataset['filenames'].iloc[i]
        
#         pix_matrix = original_data[b'data'][row]

#         # Consolidated stacking/reshaping from earlier
#         target = np.dstack((
#             pix_matrix[0:1024].reshape(32,32),
#             pix_matrix[1024:2048].reshape(32,32),
#             pix_matrix[2048:].reshape(32,32)
#         ))
        
#         # Save the image
#         plt.imsave(os.path.join(root_dir, filename), target)

#     # Return any signal data you want for debugging
#     return

# ## save ALL images using the save_images function
# save_images(df_train, './train/', dataset_train)
# save_images(df_test, './test/', dataset_test)

# %%
# Method 2
# Better one

from pandarallel import pandarallel

pandarallel.initialize(nb_workers=2, progress_bar=True, use_memory_fs=True)

data = {
    'train_df': df_train,
    'train_dataset': dataset_train,
    'test_df': df_test,
    'test_dataset': dataset_test
}

def save_images(row, batch, dataset):
    file_path = os.path.join(batch, row.filenames)
    arr = dataset[row.row]
    
    target = np.dstack((
            arr[0:1024].reshape(32,32),
            arr[1024:2048].reshape(32,32),
            arr[2048:].reshape(32,32)
    ))

    plt.imsave(file_path, target)
    
for batch in ('test', 'train'):
    _ = data[f"{batch}_df"].parallel_apply(
        save_images,
        batch=f'./{batch}',
        dataset=data[f'{batch}_dataset'][b'data'],
        axis=1
    )
# Out:
# INFO: Pandarallel will run on 2 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%'), Label(value='0 / 100'))), HBox(childr…
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=500), Label(value='0 / 500'))), HB…

# %% [markdown]
# ### 3. Load the data
#
# Now we can load the data into S3.
#
# Using the sagemaker SDK grab the current region, execution role, and bucket.

# %%
import boto3
my_session = boto3.session.Session()
my_region = my_session.region_name

# %%
import sagemaker

session = sagemaker.Session()

bucket= session.default_bucket()
print("Default Bucket: {}".format(bucket))

region =  boto3.session.Session().region_name
print("AWS Region: {}".format(region))

role = sagemaker.get_execution_role()
print("RoleArn: {}".format(role))
# Out:
# Default Bucket: sagemaker-ap-southeast-1-263436898058
# AWS Region: ap-southeast-1
# RoleArn: arn:aws:iam::263436898058:role/trustcodes-ml

# %% [markdown]
# With this data we can easily sync your data up into S3!

# %%
import os

os.environ["DEFAULT_S3_BUCKET"] = bucket
# !aws s3 sync ./train s3://${DEFAULT_S3_BUCKET}/train/
# !aws s3 sync ./test s3://${DEFAULT_S3_BUCKET}/test/
# Out:
# upload: train/bicycle_s_000017.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_000017.png
# upload: train/bicycle_s_000039.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_000039.png
# upload: train/bicycle_s_000066.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_000066.png
# upload: train/bicycle_s_000051.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_000051.png
# upload: train/bicycle_s_000038.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_000038.png
# upload: train/bicycle_s_000043.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_000043.png
# upload: train/bicycle_s_000137.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_000137.png
# upload: train/bicycle_s_000021.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_000021.png
# upload: train/bicycle_s_000035.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_000035.png
# upload: train/bicycle_s_000159.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_000159.png
# upload: train/bicycle_s_000149.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_000149.png
# upload: train/bicycle_s_000156.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_000156.png
# upload: train/bicycle_s_000071.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_000071.png
# upload: train/bicycle_s_000180.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_000180.png
# upload: train/bicycle_s_000124.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_000124.png
# upload: train/bicycle_s_000147.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_000147.png
# upload: train/bicycle_s_000099.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_000099.png
# upload: train/bicycle_s_000231.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_000231.png
# upload: train/bicycle_s_000243.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_000243.png
# upload: train/bicycle_s_000314.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_000314.png
# upload: train/bicycle_s_000282.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_000282.png
# upload: train/bicycle_s_000279.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_000279.png
# upload: train/bicycle_s_000396.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_000396.png
# upload: train/bicycle_s_000369.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_000369.png
# upload: train/bicycle_s_000392.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_000392.png
# upload: train/bicycle_s_000371.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_000371.png
# upload: train/bicycle_s_000235.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_000235.png
# upload: train/bicycle_s_000435.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_000435.png
# upload: train/bicycle_s_000399.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_000399.png
# upload: train/bicycle_s_000437.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_000437.png
# upload: train/bicycle_s_000463.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_000463.png
# upload: train/bicycle_s_000408.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_000408.png
# upload: train/bicycle_s_000467.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_000467.png
# upload: train/bicycle_s_000491.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_000491.png
# upload: train/bicycle_s_000522.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_000522.png
# upload: train/bicycle_s_000536.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_000536.png
# upload: train/bicycle_s_000537.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_000537.png
# upload: train/bicycle_s_000569.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_000569.png
# upload: train/bicycle_s_000668.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_000668.png
# upload: train/bicycle_s_000667.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_000667.png
# upload: train/bicycle_s_000546.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_000546.png
# upload: train/bicycle_s_000723.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_000723.png
# upload: train/bicycle_s_000774.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_000774.png
# upload: train/bicycle_s_000753.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_000753.png
# upload: train/bicycle_s_000561.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_000561.png
# upload: train/bicycle_s_000759.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_000759.png
# upload: train/bicycle_s_000778.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_000778.png
# upload: train/bicycle_s_000782.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_000782.png
# upload: train/bicycle_s_000861.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_000861.png
# upload: train/bicycle_s_000775.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_000775.png
# upload: train/bicycle_s_000785.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_000785.png
# upload: train/bicycle_s_000781.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_000781.png
# upload: train/bicycle_s_000829.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_000829.png
# upload: train/bicycle_s_000822.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_000822.png
# upload: train/bicycle_s_000951.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_000951.png
# upload: train/bicycle_s_000986.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_000986.png
# upload: train/bicycle_s_001002.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_001002.png
# upload: train/bicycle_s_001111.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_001111.png
# upload: train/bicycle_s_000978.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_000978.png
# upload: train/bicycle_s_000996.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_000996.png
# upload: train/bicycle_s_001168.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_001168.png
# upload: train/bicycle_s_001205.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_001205.png
# upload: train/bicycle_s_001174.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_001174.png
# upload: train/bicycle_s_001228.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_001228.png
# upload: train/bicycle_s_001338.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_001338.png
# upload: train/bicycle_s_001203.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_001203.png
# upload: train/bicycle_s_001348.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_001348.png
# upload: train/bicycle_s_001388.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_001388.png
# upload: train/bicycle_s_001247.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_001247.png
# upload: train/bicycle_s_001245.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_001245.png
# upload: train/bicycle_s_001402.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_001402.png
# upload: train/bicycle_s_001409.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_001409.png
# upload: train/bicycle_s_001411.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_001411.png
# upload: train/bicycle_s_001452.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_001452.png
# upload: train/bicycle_s_001554.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_001554.png
# upload: train/bicycle_s_001448.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_001448.png
# upload: train/bicycle_s_001642.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_001642.png
# upload: train/bicycle_s_001583.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_001583.png
# upload: train/bicycle_s_001470.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_001470.png
# upload: train/bicycle_s_001663.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_001663.png
# upload: train/bicycle_s_001679.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_001679.png
# upload: train/bicycle_s_001569.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_001569.png
# upload: train/bicycle_s_001673.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_001673.png
# upload: train/bicycle_s_001681.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_001681.png
# upload: train/bicycle_s_001688.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_001688.png
# upload: train/bicycle_s_001748.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_001748.png
# upload: train/bicycle_s_001814.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_001814.png
# upload: train/bicycle_s_001687.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_001687.png
# upload: train/bicycle_s_001693.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_001693.png
# upload: train/bicycle_s_001928.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_001928.png
# upload: train/bicycle_s_001757.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_001757.png
# upload: train/bicycle_s_001904.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_001904.png
# upload: train/bicycle_s_002005.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_002005.png
# upload: train/bicycle_s_001956.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_001956.png
# upload: train/bicycle_s_002100.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_002100.png
# upload: train/bicycle_s_002029.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_002029.png
# upload: train/bicycle_s_002129.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_002129.png
# upload: train/bicycle_s_002049.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_002049.png
# upload: train/bicycle_s_002012.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_002012.png
# upload: train/bicycle_s_002132.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_002132.png
# upload: train/bicycle_s_002222.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_002222.png
# upload: train/bicycle_s_002338.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_002338.png
# upload: train/bicycle_s_002299.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_002299.png
# upload: train/bicycle_s_002218.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_002218.png
# upload: train/bicycle_s_002237.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_002237.png
# upload: train/bicycle_s_002153.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_002153.png
# upload: train/bicycle_s_002258.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_002258.png
# upload: train/bicycle_s_002374.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_002374.png
# upload: train/bicycle_s_002247.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_002247.png
# upload: train/bicycle_s_002373.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_002373.png
# upload: train/bicycle_s_002400.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_002400.png
# upload: train/bicycle_s_002475.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_002475.png
# upload: train/bicycle_s_002436.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_002436.png
# upload: train/bicycle_s_002448.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_002448.png
# upload: train/bicycle_s_002410.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_002410.png
# upload: train/bicycle_s_002550.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_002550.png
# upload: train/bicycle_s_002521.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_002521.png
# upload: train/bicycle_s_002569.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_002569.png
# upload: train/bicycle_s_002711.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_002711.png
# upload: train/bicycle_s_002624.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_002624.png
# upload: train/bicycle_s_002661.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_002661.png
# upload: train/bicycle_s_002715.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_002715.png
# upload: train/bicycle_s_002725.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_002725.png
# upload: train/bicycle_s_002669.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_002669.png
# upload: train/bicycle_s_002759.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_002759.png
# upload: train/bicycle_s_002729.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_002729.png
# upload: train/bicycle_s_002728.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_002728.png
# upload: train/bicycle_s_002762.png to s3://sagemaker-ap-southeast-1-263436898058/train/bicycle_s_002762.png
# upload: train/bike_s_000003.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_000003.png
# upload: train/bike_s_000005.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_000005.png
# upload: train/bike_s_000021.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_000021.png
# upload: train/bike_s_000015.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_000015.png
# upload: train/bike_s_000018.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_000018.png
# upload: train/bike_s_000025.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_000025.png
# upload: train/bike_s_000023.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_000023.png
# upload: train/bike_s_000001.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_000001.png
# upload: train/bike_s_000024.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_000024.png
# upload: train/bike_s_000034.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_000034.png
# upload: train/bike_s_000026.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_000026.png
# upload: train/bike_s_000062.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_000062.png
# upload: train/bike_s_000035.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_000035.png
# upload: train/bike_s_000040.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_000040.png
# upload: train/bike_s_000111.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_000111.png
# upload: train/bike_s_000051.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_000051.png
# upload: train/bike_s_000154.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_000154.png
# upload: train/bike_s_000121.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_000121.png
# upload: train/bike_s_000127.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_000127.png
# upload: train/bike_s_000162.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_000162.png
# upload: train/bike_s_000129.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_000129.png
# upload: train/bike_s_000164.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_000164.png
# upload: train/bike_s_000256.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_000256.png
# upload: train/bike_s_000299.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_000299.png
# upload: train/bike_s_000237.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_000237.png
# upload: train/bike_s_000204.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_000204.png
# upload: train/bike_s_000364.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_000364.png
# upload: train/bike_s_000392.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_000392.png
# upload: train/bike_s_000390.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_000390.png
# upload: train/bike_s_000302.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_000302.png
# upload: train/bike_s_000397.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_000397.png
# upload: train/bike_s_000336.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_000336.png
# upload: train/bike_s_000474.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_000474.png
# upload: train/bike_s_000304.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_000304.png
# upload: train/bike_s_000516.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_000516.png
# upload: train/bike_s_000506.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_000506.png
# upload: train/bike_s_000545.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_000545.png
# upload: train/bike_s_000544.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_000544.png
# upload: train/bike_s_000593.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_000593.png
# upload: train/bike_s_000555.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_000555.png
# upload: train/bike_s_000522.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_000522.png
# upload: train/bike_s_000628.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_000628.png
# upload: train/bike_s_000679.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_000679.png
# upload: train/bike_s_000657.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_000657.png
# upload: train/bike_s_000682.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_000682.png
# upload: train/bike_s_000855.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_000855.png
# upload: train/bike_s_000722.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_000722.png
# upload: train/bike_s_000926.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_000926.png
# upload: train/bike_s_000990.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_000990.png
# upload: train/bike_s_000934.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_000934.png
# upload: train/bike_s_001027.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_001027.png
# upload: train/bike_s_001078.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_001078.png
# upload: train/bike_s_001093.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_001093.png
# upload: train/bike_s_001131.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_001131.png
# upload: train/bike_s_001113.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_001113.png
# upload: train/bike_s_001072.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_001072.png
# upload: train/bike_s_001116.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_001116.png
# upload: train/bike_s_001414.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_001414.png
# upload: train/bike_s_001418.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_001418.png
# upload: train/bike_s_001320.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_001320.png
# upload: train/bike_s_001260.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_001260.png
# upload: train/bike_s_001380.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_001380.png
# upload: train/bike_s_001200.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_001200.png
# upload: train/bike_s_001415.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_001415.png
# upload: train/bike_s_001226.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_001226.png
# upload: train/bike_s_001462.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_001462.png
# upload: train/bike_s_001375.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_001375.png
# upload: train/bike_s_001517.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_001517.png
# upload: train/bike_s_001613.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_001613.png
# upload: train/bike_s_001519.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_001519.png
# upload: train/bike_s_001683.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_001683.png
# upload: train/bike_s_001572.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_001572.png
# upload: train/bike_s_001739.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_001739.png
# upload: train/bike_s_001592.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_001592.png
# upload: train/bike_s_001761.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_001761.png
# upload: train/bike_s_001767.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_001767.png
# upload: train/bike_s_001679.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_001679.png
# upload: train/bike_s_001839.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_001839.png
# upload: train/bike_s_001827.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_001827.png
# upload: train/bike_s_001847.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_001847.png
# upload: train/bike_s_001876.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_001876.png
# upload: train/bike_s_001897.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_001897.png
# upload: train/bike_s_001877.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_001877.png
# upload: train/bike_s_001945.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_001945.png
# upload: train/bike_s_001915.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_001915.png
# upload: train/bike_s_001980.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_001980.png
# upload: train/bike_s_001928.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_001928.png
# upload: train/bike_s_002024.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_002024.png
# upload: train/bike_s_002033.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_002033.png
# upload: train/bike_s_002042.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_002042.png
# upload: train/bike_s_002118.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_002118.png
# upload: train/bike_s_002139.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_002139.png
# upload: train/bike_s_002090.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_002090.png
# upload: train/bike_s_001882.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_001882.png
# upload: train/bike_s_002098.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_002098.png
# upload: train/bike_s_002164.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_002164.png
# upload: train/bike_s_002203.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_002203.png
# upload: train/bike_s_002047.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_002047.png
# upload: train/bike_s_002222.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_002222.png
# upload: train/bike_s_002109.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_002109.png
# upload: train/cycle_s_000042.png to s3://sagemaker-ap-southeast-1-263436898058/train/cycle_s_000042.png
# upload: train/cycle_s_000222.png to s3://sagemaker-ap-southeast-1-263436898058/train/cycle_s_000222.png
# upload: train/bike_s_002215.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_002215.png
# upload: train/bike_s_002277.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_002277.png
# upload: train/bike_s_002283.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_002283.png
# upload: train/bike_s_002288.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_002288.png
# upload: train/cycle_s_000318.png to s3://sagemaker-ap-southeast-1-263436898058/train/cycle_s_000318.png
# upload: train/cycle_s_000463.png to s3://sagemaker-ap-southeast-1-263436898058/train/cycle_s_000463.png
# upload: train/cycle_s_000492.png to s3://sagemaker-ap-southeast-1-263436898058/train/cycle_s_000492.png
# upload: train/bike_s_002292.png to s3://sagemaker-ap-southeast-1-263436898058/train/bike_s_002292.png
# upload: train/cycle_s_000718.png to s3://sagemaker-ap-southeast-1-263436898058/train/cycle_s_000718.png
# upload: train/cycle_s_000583.png to s3://sagemaker-ap-southeast-1-263436898058/train/cycle_s_000583.png
# upload: train/cycle_s_000639.png to s3://sagemaker-ap-southeast-1-263436898058/train/cycle_s_000639.png
# upload: train/cycle_s_000666.png to s3://sagemaker-ap-southeast-1-263436898058/train/cycle_s_000666.png
# upload: train/cycle_s_000871.png to s3://sagemaker-ap-southeast-1-263436898058/train/cycle_s_000871.png
# upload: train/cycle_s_000899.png to s3://sagemaker-ap-southeast-1-263436898058/train/cycle_s_000899.png
# upload: train/cycle_s_001309.png to s3://sagemaker-ap-southeast-1-263436898058/train/cycle_s_001309.png
# upload: train/cycle_s_001412.png to s3://sagemaker-ap-southeast-1-263436898058/train/cycle_s_001412.png
# upload: train/cycle_s_001374.png to s3://sagemaker-ap-southeast-1-263436898058/train/cycle_s_001374.png
# upload: train/cycle_s_001286.png to s3://sagemaker-ap-southeast-1-263436898058/train/cycle_s_001286.png
# upload: train/cycle_s_001439.png to s3://sagemaker-ap-southeast-1-263436898058/train/cycle_s_001439.png
# upload: train/cycle_s_001413.png to s3://sagemaker-ap-southeast-1-263436898058/train/cycle_s_001413.png
# upload: train/cycle_s_001474.png to s3://sagemaker-ap-southeast-1-263436898058/train/cycle_s_001474.png
# upload: train/cycle_s_001472.png to s3://sagemaker-ap-southeast-1-263436898058/train/cycle_s_001472.png
# upload: train/cycle_s_001477.png to s3://sagemaker-ap-southeast-1-263436898058/train/cycle_s_001477.png
# upload: train/cycle_s_001640.png to s3://sagemaker-ap-southeast-1-263436898058/train/cycle_s_001640.png
# upload: train/cycle_s_001875.png to s3://sagemaker-ap-southeast-1-263436898058/train/cycle_s_001875.png
# upload: train/cycle_s_001745.png to s3://sagemaker-ap-southeast-1-263436898058/train/cycle_s_001745.png
# upload: train/cycle_s_001976.png to s3://sagemaker-ap-southeast-1-263436898058/train/cycle_s_001976.png
# upload: train/cycle_s_002053.png to s3://sagemaker-ap-southeast-1-263436898058/train/cycle_s_002053.png
# upload: train/cycle_s_001735.png to s3://sagemaker-ap-southeast-1-263436898058/train/cycle_s_001735.png
# upload: train/cycle_s_002092.png to s3://sagemaker-ap-southeast-1-263436898058/train/cycle_s_002092.png
# upload: train/cycle_s_002015.png to s3://sagemaker-ap-southeast-1-263436898058/train/cycle_s_002015.png
# upload: train/cycle_s_002093.png to s3://sagemaker-ap-southeast-1-263436898058/train/cycle_s_002093.png
# upload: train/cycle_s_002090.png to s3://sagemaker-ap-southeast-1-263436898058/train/cycle_s_002090.png
# upload: train/cycle_s_002399.png to s3://sagemaker-ap-southeast-1-263436898058/train/cycle_s_002399.png
# upload: train/cycle_s_002503.png to s3://sagemaker-ap-southeast-1-263436898058/train/cycle_s_002503.png
# upload: train/cycle_s_002598.png to s3://sagemaker-ap-southeast-1-263436898058/train/cycle_s_002598.png
# upload: train/cycle_s_002651.png to s3://sagemaker-ap-southeast-1-263436898058/train/cycle_s_002651.png
# upload: train/cycle_s_002666.png to s3://sagemaker-ap-southeast-1-263436898058/train/cycle_s_002666.png
# upload: train/cycle_s_002659.png to s3://sagemaker-ap-southeast-1-263436898058/train/cycle_s_002659.png
# upload: train/cycle_s_002178.png to s3://sagemaker-ap-southeast-1-263436898058/train/cycle_s_002178.png
# upload: train/cycle_s_002703.png to s3://sagemaker-ap-southeast-1-263436898058/train/cycle_s_002703.png
# upload: train/cycle_s_002746.png to s3://sagemaker-ap-southeast-1-263436898058/train/cycle_s_002746.png
# upload: train/cycle_s_002844.png to s3://sagemaker-ap-southeast-1-263436898058/train/cycle_s_002844.png
# upload: train/cycle_s_002882.png to s3://sagemaker-ap-southeast-1-263436898058/train/cycle_s_002882.png
# upload: train/cycle_s_002978.png to s3://sagemaker-ap-southeast-1-263436898058/train/cycle_s_002978.png
# upload: train/cycle_s_002904.png to s3://sagemaker-ap-southeast-1-263436898058/train/cycle_s_002904.png
# upload: train/cycle_s_003006.png to s3://sagemaker-ap-southeast-1-263436898058/train/cycle_s_003006.png
# upload: train/cycle_s_002779.png to s3://sagemaker-ap-southeast-1-263436898058/train/cycle_s_002779.png
# upload: train/cycle_s_003008.png to s3://sagemaker-ap-southeast-1-263436898058/train/cycle_s_003008.png
# upload: train/cycle_s_002638.png to s3://sagemaker-ap-southeast-1-263436898058/train/cycle_s_002638.png
# upload: train/cycle_s_002168.png to s3://sagemaker-ap-southeast-1-263436898058/train/cycle_s_002168.png
# upload: train/cycle_s_003026.png to s3://sagemaker-ap-southeast-1-263436898058/train/cycle_s_003026.png
# upload: train/dirt_bike_s_000017.png to s3://sagemaker-ap-southeast-1-263436898058/train/dirt_bike_s_000017.png
# upload: train/cycle_s_003122.png to s3://sagemaker-ap-southeast-1-263436898058/train/cycle_s_003122.png
# upload: train/cycle_s_003147.png to s3://sagemaker-ap-southeast-1-263436898058/train/cycle_s_003147.png
# upload: train/dirt_bike_s_000005.png to s3://sagemaker-ap-southeast-1-263436898058/train/dirt_bike_s_000005.png
# upload: train/cycle_s_003043.png to s3://sagemaker-ap-southeast-1-263436898058/train/cycle_s_003043.png
# upload: train/cycle_s_003162.png to s3://sagemaker-ap-southeast-1-263436898058/train/cycle_s_003162.png
# upload: train/dirt_bike_s_000030.png to s3://sagemaker-ap-southeast-1-263436898058/train/dirt_bike_s_000030.png
# upload: train/cycle_s_003148.png to s3://sagemaker-ap-southeast-1-263436898058/train/cycle_s_003148.png
# upload: train/dirt_bike_s_000003.png to s3://sagemaker-ap-southeast-1-263436898058/train/dirt_bike_s_000003.png
# upload: train/dirt_bike_s_000134.png to s3://sagemaker-ap-southeast-1-263436898058/train/dirt_bike_s_000134.png
# upload: train/dirt_bike_s_000119.png to s3://sagemaker-ap-southeast-1-263436898058/train/dirt_bike_s_000119.png
# upload: train/dirt_bike_s_000124.png to s3://sagemaker-ap-southeast-1-263436898058/train/dirt_bike_s_000124.png
# upload: train/dirt_bike_s_000059.png to s3://sagemaker-ap-southeast-1-263436898058/train/dirt_bike_s_000059.png
# upload: train/minibike_s_000010.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000010.png
# upload: train/minibike_s_000022.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000022.png
# upload: train/minibike_s_000020.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000020.png
# upload: train/minibike_s_000011.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000011.png
# upload: train/minibike_s_000036.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000036.png
# upload: train/minibike_s_000102.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000102.png
# upload: train/minibike_s_000099.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000099.png
# upload: train/minibike_s_000035.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000035.png
# upload: train/minibike_s_000064.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000064.png
# upload: train/minibike_s_000121.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000121.png
# upload: train/minibike_s_000110.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000110.png
# upload: train/minibike_s_000116.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000116.png
# upload: train/minibike_s_000108.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000108.png
# upload: train/minibike_s_000127.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000127.png
# upload: train/minibike_s_000146.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000146.png
# upload: train/minibike_s_000130.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000130.png
# upload: train/minibike_s_000165.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000165.png
# upload: train/minibike_s_000203.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000203.png
# upload: train/minibike_s_000117.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000117.png
# upload: train/minibike_s_000244.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000244.png
# upload: train/minibike_s_000293.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000293.png
# upload: train/minibike_s_000324.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000324.png
# upload: train/minibike_s_000314.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000314.png
# upload: train/minibike_s_000335.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000335.png
# upload: train/minibike_s_000149.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000149.png
# upload: train/minibike_s_000401.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000401.png
# upload: train/minibike_s_000350.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000350.png
# upload: train/minibike_s_000408.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000408.png
# upload: train/minibike_s_000409.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000409.png
# upload: train/minibike_s_000402.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000402.png
# upload: train/minibike_s_000427.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000427.png
# upload: train/minibike_s_000218.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000218.png
# upload: train/minibike_s_000362.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000362.png
# upload: train/minibike_s_000434.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000434.png
# upload: train/minibike_s_000435.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000435.png
# upload: train/minibike_s_000459.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000459.png
# upload: train/minibike_s_000485.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000485.png
# upload: train/minibike_s_000429.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000429.png
# upload: train/minibike_s_000340.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000340.png
# upload: train/minibike_s_000392.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000392.png
# upload: train/minibike_s_000451.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000451.png
# upload: train/minibike_s_000507.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000507.png
# upload: train/minibike_s_000498.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000498.png
# upload: train/minibike_s_000518.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000518.png
# upload: train/minibike_s_000522.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000522.png
# upload: train/minibike_s_000527.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000527.png
# upload: train/minibike_s_000526.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000526.png
# upload: train/minibike_s_000565.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000565.png
# upload: train/minibike_s_000491.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000491.png
# upload: train/minibike_s_000511.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000511.png
# upload: train/minibike_s_000519.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000519.png
# upload: train/minibike_s_000568.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000568.png
# upload: train/minibike_s_000520.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000520.png
# upload: train/minibike_s_000570.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000570.png
# upload: train/minibike_s_000566.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000566.png
# upload: train/minibike_s_000567.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000567.png
# upload: train/minibike_s_000652.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000652.png
# upload: train/minibike_s_000569.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000569.png
# upload: train/minibike_s_000690.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000690.png
# upload: train/minibike_s_000698.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000698.png
# upload: train/minibike_s_000709.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000709.png
# upload: train/minibike_s_000701.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000701.png
# upload: train/minibike_s_000571.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000571.png
# upload: train/minibike_s_000654.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000654.png
# upload: train/minibike_s_000738.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000738.png
# upload: train/minibike_s_000613.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000613.png
# upload: train/minibike_s_000813.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000813.png
# upload: train/minibike_s_000743.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000743.png
# upload: train/minibike_s_000800.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000800.png
# upload: train/minibike_s_000802.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000802.png
# upload: train/minibike_s_000824.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000824.png
# upload: train/minibike_s_000830.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000830.png
# upload: train/minibike_s_000855.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000855.png
# upload: train/minibike_s_000885.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000885.png
# upload: train/minibike_s_000820.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000820.png
# upload: train/minibike_s_000831.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000831.png
# upload: train/minibike_s_000741.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000741.png
# upload: train/minibike_s_000886.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000886.png
# upload: train/minibike_s_000914.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000914.png
# upload: train/minibike_s_000967.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000967.png
# upload: train/minibike_s_001016.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001016.png
# upload: train/minibike_s_001072.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001072.png
# upload: train/minibike_s_001079.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001079.png
# upload: train/minibike_s_000968.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000968.png
# upload: train/minibike_s_001017.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001017.png
# upload: train/minibike_s_001094.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001094.png
# upload: train/minibike_s_001168.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001168.png
# upload: train/minibike_s_001177.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001177.png
# upload: train/minibike_s_001157.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001157.png
# upload: train/minibike_s_001169.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001169.png
# upload: train/minibike_s_001185.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001185.png
# upload: train/minibike_s_000906.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_000906.png
# upload: train/minibike_s_001193.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001193.png
# upload: train/minibike_s_001249.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001249.png
# upload: train/minibike_s_001250.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001250.png
# upload: train/minibike_s_001179.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001179.png
# upload: train/minibike_s_001261.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001261.png
# upload: train/minibike_s_001270.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001270.png
# upload: train/minibike_s_001191.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001191.png
# upload: train/minibike_s_001275.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001275.png
# upload: train/minibike_s_001279.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001279.png
# upload: train/minibike_s_001344.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001344.png
# upload: train/minibike_s_001294.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001294.png
# upload: train/minibike_s_001366.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001366.png
# upload: train/minibike_s_001348.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001348.png
# upload: train/minibike_s_001345.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001345.png
# upload: train/minibike_s_001417.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001417.png
# upload: train/minibike_s_001479.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001479.png
# upload: train/minibike_s_001450.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001450.png
# upload: train/minibike_s_001458.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001458.png
# upload: train/minibike_s_001496.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001496.png
# upload: train/minibike_s_001498.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001498.png
# upload: train/minibike_s_001491.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001491.png
# upload: train/minibike_s_001539.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001539.png
# upload: train/minibike_s_001511.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001511.png
# upload: train/minibike_s_001546.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001546.png
# upload: train/minibike_s_001506.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001506.png
# upload: train/minibike_s_001558.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001558.png
# upload: train/minibike_s_001512.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001512.png
# upload: train/minibike_s_001565.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001565.png
# upload: train/minibike_s_001573.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001573.png
# upload: train/minibike_s_001575.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001575.png
# upload: train/minibike_s_001540.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001540.png
# upload: train/minibike_s_001638.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001638.png
# upload: train/minibike_s_001597.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001597.png
# upload: train/minibike_s_001691.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001691.png
# upload: train/minibike_s_001689.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001689.png
# upload: train/minibike_s_001639.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001639.png
# upload: train/minibike_s_001701.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001701.png
# upload: train/minibike_s_001631.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001631.png
# upload: train/minibike_s_001653.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001653.png
# upload: train/minibike_s_001731.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001731.png
# upload: train/minibike_s_001734.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001734.png
# upload: train/minibike_s_001827.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001827.png
# upload: train/minibike_s_001747.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001747.png
# upload: train/minibike_s_001829.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001829.png
# upload: train/minibike_s_001771.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001771.png
# upload: train/minibike_s_001836.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001836.png
# upload: train/minibike_s_001865.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001865.png
# upload: train/minibike_s_001789.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001789.png
# upload: train/minibike_s_001863.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001863.png
# upload: train/minibike_s_001767.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001767.png
# upload: train/minibike_s_001838.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001838.png
# upload: train/minibike_s_001873.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001873.png
# upload: train/minibike_s_001870.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001870.png
# upload: train/minibike_s_001917.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001917.png
# upload: train/minibike_s_001881.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001881.png
# upload: train/minibike_s_001921.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001921.png
# upload: train/minibike_s_001885.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001885.png
# upload: train/minibike_s_001996.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001996.png
# upload: train/minibike_s_001944.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001944.png
# upload: train/minibike_s_001969.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_001969.png
# upload: train/minibike_s_002009.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_002009.png
# upload: train/minibike_s_002030.png to s3://sagemaker-ap-southeast-1-263436898058/train/minibike_s_002030.png
# ...
# upload: test/minibike_s_000055.png to s3://sagemaker-ap-southeast-1-263436898058/test/minibike_s_000055.png
# upload: test/minibike_s_000309.png to s3://sagemaker-ap-southeast-1-263436898058/test/minibike_s_000309.png
# upload: test/minibike_s_000828.png to s3://sagemaker-ap-southeast-1-263436898058/test/minibike_s_000828.png
# upload: test/minibike_s_000573.png to s3://sagemaker-ap-southeast-1-263436898058/test/minibike_s_000573.png
# upload: test/minibike_s_000052.png to s3://sagemaker-ap-southeast-1-263436898058/test/minibike_s_000052.png
# upload: test/minibike_s_000792.png to s3://sagemaker-ap-southeast-1-263436898058/test/minibike_s_000792.png
# upload: test/cycle_s_002964.png to s3://sagemaker-ap-southeast-1-263436898058/test/cycle_s_002964.png
# upload: test/minibike_s_000947.png to s3://sagemaker-ap-southeast-1-263436898058/test/minibike_s_000947.png
# upload: test/minibike_s_000801.png to s3://sagemaker-ap-southeast-1-263436898058/test/minibike_s_000801.png
# upload: test/minibike_s_000398.png to s3://sagemaker-ap-southeast-1-263436898058/test/minibike_s_000398.png
# upload: test/minibike_s_001089.png to s3://sagemaker-ap-southeast-1-263436898058/test/minibike_s_001089.png
# upload: test/minibike_s_001441.png to s3://sagemaker-ap-southeast-1-263436898058/test/minibike_s_001441.png
# upload: test/minibike_s_000505.png to s3://sagemaker-ap-southeast-1-263436898058/test/minibike_s_000505.png
# upload: test/minibike_s_001732.png to s3://sagemaker-ap-southeast-1-263436898058/test/minibike_s_001732.png
# upload: test/minibike_s_000497.png to s3://sagemaker-ap-southeast-1-263436898058/test/minibike_s_000497.png
# upload: test/minibike_s_001473.png to s3://sagemaker-ap-southeast-1-263436898058/test/minibike_s_001473.png
# upload: test/minibike_s_000913.png to s3://sagemaker-ap-southeast-1-263436898058/test/minibike_s_000913.png
# upload: test/minibike_s_000960.png to s3://sagemaker-ap-southeast-1-263436898058/test/minibike_s_000960.png
# upload: test/minibike_s_001867.png to s3://sagemaker-ap-southeast-1-263436898058/test/minibike_s_001867.png
# upload: test/minibike_s_000880.png to s3://sagemaker-ap-southeast-1-263436898058/test/minibike_s_000880.png
# upload: test/moped_s_000064.png to s3://sagemaker-ap-southeast-1-263436898058/test/moped_s_000064.png
# upload: test/minibike_s_002051.png to s3://sagemaker-ap-southeast-1-263436898058/test/minibike_s_002051.png
# upload: test/moped_s_000007.png to s3://sagemaker-ap-southeast-1-263436898058/test/moped_s_000007.png
# upload: test/minibike_s_001893.png to s3://sagemaker-ap-southeast-1-263436898058/test/minibike_s_001893.png
# upload: test/minibike_s_001547.png to s3://sagemaker-ap-southeast-1-263436898058/test/minibike_s_001547.png
# upload: test/minibike_s_001651.png to s3://sagemaker-ap-southeast-1-263436898058/test/minibike_s_001651.png
# upload: test/minibike_s_001605.png to s3://sagemaker-ap-southeast-1-263436898058/test/minibike_s_001605.png
# upload: test/minibike_s_002230.png to s3://sagemaker-ap-southeast-1-263436898058/test/minibike_s_002230.png
# upload: test/moped_s_000033.png to s3://sagemaker-ap-southeast-1-263436898058/test/moped_s_000033.png
# upload: test/minibike_s_002227.png to s3://sagemaker-ap-southeast-1-263436898058/test/minibike_s_002227.png
# upload: test/moped_s_000306.png to s3://sagemaker-ap-southeast-1-263436898058/test/moped_s_000306.png
# upload: test/motorbike_s_000135.png to s3://sagemaker-ap-southeast-1-263436898058/test/motorbike_s_000135.png
# upload: test/motorbike_s_000121.png to s3://sagemaker-ap-southeast-1-263436898058/test/motorbike_s_000121.png
# upload: test/motorbike_s_000126.png to s3://sagemaker-ap-southeast-1-263436898058/test/motorbike_s_000126.png
# upload: test/motorbike_s_000433.png to s3://sagemaker-ap-southeast-1-263436898058/test/motorbike_s_000433.png
# upload: test/motorbike_s_000324.png to s3://sagemaker-ap-southeast-1-263436898058/test/motorbike_s_000324.png
# upload: test/minibike_s_002173.png to s3://sagemaker-ap-southeast-1-263436898058/test/minibike_s_002173.png
# upload: test/motorbike_s_000465.png to s3://sagemaker-ap-southeast-1-263436898058/test/motorbike_s_000465.png
# upload: test/motorbike_s_000333.png to s3://sagemaker-ap-southeast-1-263436898058/test/motorbike_s_000333.png
# upload: test/motorbike_s_000629.png to s3://sagemaker-ap-southeast-1-263436898058/test/motorbike_s_000629.png
# upload: test/motorcycle_s_000007.png to s3://sagemaker-ap-southeast-1-263436898058/test/motorcycle_s_000007.png
# upload: test/motorcycle_s_000040.png to s3://sagemaker-ap-southeast-1-263436898058/test/motorcycle_s_000040.png
# upload: test/motorbike_s_000005.png to s3://sagemaker-ap-southeast-1-263436898058/test/motorbike_s_000005.png
# upload: test/motorcycle_s_000042.png to s3://sagemaker-ap-southeast-1-263436898058/test/motorcycle_s_000042.png
# upload: test/motorcycle_s_000060.png to s3://sagemaker-ap-southeast-1-263436898058/test/motorcycle_s_000060.png
# upload: test/motorcycle_s_000049.png to s3://sagemaker-ap-southeast-1-263436898058/test/motorcycle_s_000049.png
# upload: test/motorcycle_s_000211.png to s3://sagemaker-ap-southeast-1-263436898058/test/motorcycle_s_000211.png
# upload: test/motorcycle_s_000139.png to s3://sagemaker-ap-southeast-1-263436898058/test/motorcycle_s_000139.png
# upload: test/motorcycle_s_000141.png to s3://sagemaker-ap-southeast-1-263436898058/test/motorcycle_s_000141.png
# upload: test/motorcycle_s_000063.png to s3://sagemaker-ap-southeast-1-263436898058/test/motorcycle_s_000063.png
# upload: test/motorcycle_s_000171.png to s3://sagemaker-ap-southeast-1-263436898058/test/motorcycle_s_000171.png
# upload: test/motorcycle_s_000352.png to s3://sagemaker-ap-southeast-1-263436898058/test/motorcycle_s_000352.png
# upload: test/motorcycle_s_000222.png to s3://sagemaker-ap-southeast-1-263436898058/test/motorcycle_s_000222.png
# upload: test/motorcycle_s_000323.png to s3://sagemaker-ap-southeast-1-263436898058/test/motorcycle_s_000323.png
# upload: test/motorcycle_s_000450.png to s3://sagemaker-ap-southeast-1-263436898058/test/motorcycle_s_000450.png
# upload: test/motorcycle_s_000446.png to s3://sagemaker-ap-southeast-1-263436898058/test/motorcycle_s_000446.png
# upload: test/motorcycle_s_000512.png to s3://sagemaker-ap-southeast-1-263436898058/test/motorcycle_s_000512.png
# upload: test/motorcycle_s_000530.png to s3://sagemaker-ap-southeast-1-263436898058/test/motorcycle_s_000530.png
# upload: test/motorcycle_s_000427.png to s3://sagemaker-ap-southeast-1-263436898058/test/motorcycle_s_000427.png
# upload: test/motorcycle_s_000494.png to s3://sagemaker-ap-southeast-1-263436898058/test/motorcycle_s_000494.png
# upload: test/motorcycle_s_000485.png to s3://sagemaker-ap-southeast-1-263436898058/test/motorcycle_s_000485.png
# upload: test/motorcycle_s_000602.png to s3://sagemaker-ap-southeast-1-263436898058/test/motorcycle_s_000602.png
# upload: test/motorcycle_s_000679.png to s3://sagemaker-ap-southeast-1-263436898058/test/motorcycle_s_000679.png
# upload: test/motorcycle_s_000615.png to s3://sagemaker-ap-southeast-1-263436898058/test/motorcycle_s_000615.png
# upload: test/motorcycle_s_000606.png to s3://sagemaker-ap-southeast-1-263436898058/test/motorcycle_s_000606.png
# upload: test/motorcycle_s_000739.png to s3://sagemaker-ap-southeast-1-263436898058/test/motorcycle_s_000739.png
# upload: test/motorcycle_s_000797.png to s3://sagemaker-ap-southeast-1-263436898058/test/motorcycle_s_000797.png
# upload: test/motorcycle_s_000876.png to s3://sagemaker-ap-southeast-1-263436898058/test/motorcycle_s_000876.png
# upload: test/motorcycle_s_001164.png to s3://sagemaker-ap-southeast-1-263436898058/test/motorcycle_s_001164.png
# upload: test/motorcycle_s_000866.png to s3://sagemaker-ap-southeast-1-263436898058/test/motorcycle_s_000866.png
# upload: test/motorcycle_s_000685.png to s3://sagemaker-ap-southeast-1-263436898058/test/motorcycle_s_000685.png
# upload: test/motorcycle_s_000878.png to s3://sagemaker-ap-southeast-1-263436898058/test/motorcycle_s_000878.png
# upload: test/motorcycle_s_000963.png to s3://sagemaker-ap-southeast-1-263436898058/test/motorcycle_s_000963.png
# upload: test/motorcycle_s_000825.png to s3://sagemaker-ap-southeast-1-263436898058/test/motorcycle_s_000825.png
# upload: test/motorcycle_s_001249.png to s3://sagemaker-ap-southeast-1-263436898058/test/motorcycle_s_001249.png
# upload: test/motorcycle_s_001385.png to s3://sagemaker-ap-southeast-1-263436898058/test/motorcycle_s_001385.png
# upload: test/motorcycle_s_001508.png to s3://sagemaker-ap-southeast-1-263436898058/test/motorcycle_s_001508.png
# upload: test/motorcycle_s_001269.png to s3://sagemaker-ap-southeast-1-263436898058/test/motorcycle_s_001269.png
# upload: test/motorcycle_s_001519.png to s3://sagemaker-ap-southeast-1-263436898058/test/motorcycle_s_001519.png
# upload: test/motorcycle_s_001687.png to s3://sagemaker-ap-southeast-1-263436898058/test/motorcycle_s_001687.png
# upload: test/motorcycle_s_001782.png to s3://sagemaker-ap-southeast-1-263436898058/test/motorcycle_s_001782.png
# upload: test/motorcycle_s_001348.png to s3://sagemaker-ap-southeast-1-263436898058/test/motorcycle_s_001348.png
# upload: test/motorcycle_s_001261.png to s3://sagemaker-ap-southeast-1-263436898058/test/motorcycle_s_001261.png
# upload: test/motorcycle_s_001906.png to s3://sagemaker-ap-southeast-1-263436898058/test/motorcycle_s_001906.png
# upload: test/motorcycle_s_001892.png to s3://sagemaker-ap-southeast-1-263436898058/test/motorcycle_s_001892.png
# upload: test/motorcycle_s_001936.png to s3://sagemaker-ap-southeast-1-263436898058/test/motorcycle_s_001936.png
# upload: test/motorcycle_s_001679.png to s3://sagemaker-ap-southeast-1-263436898058/test/motorcycle_s_001679.png
# upload: test/motorcycle_s_001971.png to s3://sagemaker-ap-southeast-1-263436898058/test/motorcycle_s_001971.png
# upload: test/motorcycle_s_001960.png to s3://sagemaker-ap-southeast-1-263436898058/test/motorcycle_s_001960.png
# upload: test/motorcycle_s_002112.png to s3://sagemaker-ap-southeast-1-263436898058/test/motorcycle_s_002112.png
# upload: test/motorcycle_s_002177.png to s3://sagemaker-ap-southeast-1-263436898058/test/motorcycle_s_002177.png
# upload: test/motorcycle_s_002126.png to s3://sagemaker-ap-southeast-1-263436898058/test/motorcycle_s_002126.png
# upload: test/motorcycle_s_002026.png to s3://sagemaker-ap-southeast-1-263436898058/test/motorcycle_s_002026.png
# upload: test/ordinary_bicycle_s_000105.png to s3://sagemaker-ap-southeast-1-263436898058/test/ordinary_bicycle_s_000105.png
# upload: test/ordinary_bicycle_s_000158.png to s3://sagemaker-ap-southeast-1-263436898058/test/ordinary_bicycle_s_000158.png
# upload: test/motorcycle_s_001955.png to s3://sagemaker-ap-southeast-1-263436898058/test/motorcycle_s_001955.png
# upload: test/ordinary_bicycle_s_000113.png to s3://sagemaker-ap-southeast-1-263436898058/test/ordinary_bicycle_s_000113.png
# upload: test/safety_bicycle_s_000280.png to s3://sagemaker-ap-southeast-1-263436898058/test/safety_bicycle_s_000280.png
# upload: test/ordinary_bicycle_s_000169.png to s3://sagemaker-ap-southeast-1-263436898058/test/ordinary_bicycle_s_000169.png
# upload: test/ordinary_bicycle_s_000350.png to s3://sagemaker-ap-southeast-1-263436898058/test/ordinary_bicycle_s_000350.png
# upload: test/ordinary_bicycle_s_000431.png to s3://sagemaker-ap-southeast-1-263436898058/test/ordinary_bicycle_s_000431.png
# upload: test/safety_bicycle_s_000235.png to s3://sagemaker-ap-southeast-1-263436898058/test/safety_bicycle_s_000235.png
# upload: test/ordinary_bicycle_s_000284.png to s3://sagemaker-ap-southeast-1-263436898058/test/ordinary_bicycle_s_000284.png
# upload: test/ordinary_bicycle_s_000437.png to s3://sagemaker-ap-southeast-1-263436898058/test/ordinary_bicycle_s_000437.png
# upload: test/safety_bicycle_s_000315.png to s3://sagemaker-ap-southeast-1-263436898058/test/safety_bicycle_s_000315.png
# upload: test/safety_bicycle_s_001153.png to s3://sagemaker-ap-southeast-1-263436898058/test/safety_bicycle_s_001153.png
# upload: test/safety_bicycle_s_001322.png to s3://sagemaker-ap-southeast-1-263436898058/test/safety_bicycle_s_001322.png
# upload: test/safety_bike_s_000192.png to s3://sagemaker-ap-southeast-1-263436898058/test/safety_bike_s_000192.png
# upload: test/safety_bike_s_000390.png to s3://sagemaker-ap-southeast-1-263436898058/test/safety_bike_s_000390.png
# upload: test/safety_bicycle_s_001286.png to s3://sagemaker-ap-southeast-1-263436898058/test/safety_bicycle_s_001286.png
# upload: test/safety_bicycle_s_001575.png to s3://sagemaker-ap-southeast-1-263436898058/test/safety_bicycle_s_001575.png
# upload: test/safety_bike_s_000488.png to s3://sagemaker-ap-southeast-1-263436898058/test/safety_bike_s_000488.png
# upload: test/safety_bike_s_000438.png to s3://sagemaker-ap-southeast-1-263436898058/test/safety_bike_s_000438.png
# upload: test/safety_bike_s_000699.png to s3://sagemaker-ap-southeast-1-263436898058/test/safety_bike_s_000699.png
# upload: test/safety_bike_s_000540.png to s3://sagemaker-ap-southeast-1-263436898058/test/safety_bike_s_000540.png
# upload: test/safety_bike_s_000541.png to s3://sagemaker-ap-southeast-1-263436898058/test/safety_bike_s_000541.png
# upload: test/safety_bike_s_000791.png to s3://sagemaker-ap-southeast-1-263436898058/test/safety_bike_s_000791.png
# upload: test/safety_bike_s_001088.png to s3://sagemaker-ap-southeast-1-263436898058/test/safety_bike_s_001088.png
# upload: test/safety_bike_s_001132.png to s3://sagemaker-ap-southeast-1-263436898058/test/safety_bike_s_001132.png
# upload: test/safety_bike_s_001481.png to s3://sagemaker-ap-southeast-1-263436898058/test/safety_bike_s_001481.png
# upload: test/safety_bike_s_001087.png to s3://sagemaker-ap-southeast-1-263436898058/test/safety_bike_s_001087.png
# upload: test/safety_bike_s_001065.png to s3://sagemaker-ap-southeast-1-263436898058/test/safety_bike_s_001065.png
# upload: test/safety_bike_s_001690.png to s3://sagemaker-ap-southeast-1-263436898058/test/safety_bike_s_001690.png
# upload: test/safety_bike_s_001253.png to s3://sagemaker-ap-southeast-1-263436898058/test/safety_bike_s_001253.png
# upload: test/trail_bike_s_000073.png to s3://sagemaker-ap-southeast-1-263436898058/test/trail_bike_s_000073.png
# upload: test/velocipede_s_000001.png to s3://sagemaker-ap-southeast-1-263436898058/test/velocipede_s_000001.png
# upload: test/velocipede_s_000041.png to s3://sagemaker-ap-southeast-1-263436898058/test/velocipede_s_000041.png
# upload: test/velocipede_s_000292.png to s3://sagemaker-ap-southeast-1-263436898058/test/velocipede_s_000292.png
# upload: test/velocipede_s_000369.png to s3://sagemaker-ap-southeast-1-263436898058/test/velocipede_s_000369.png
# upload: test/velocipede_s_000106.png to s3://sagemaker-ap-southeast-1-263436898058/test/velocipede_s_000106.png
# upload: test/velocipede_s_001232.png to s3://sagemaker-ap-southeast-1-263436898058/test/velocipede_s_001232.png
# upload: test/velocipede_s_001335.png to s3://sagemaker-ap-southeast-1-263436898058/test/velocipede_s_001335.png
# upload: test/velocipede_s_001355.png to s3://sagemaker-ap-southeast-1-263436898058/test/velocipede_s_001355.png
# upload: test/velocipede_s_001633.png to s3://sagemaker-ap-southeast-1-263436898058/test/velocipede_s_001633.png
# upload: test/velocipede_s_001201.png to s3://sagemaker-ap-southeast-1-263436898058/test/velocipede_s_001201.png
# upload: test/velocipede_s_001379.png to s3://sagemaker-ap-southeast-1-263436898058/test/velocipede_s_001379.png
# upload: test/velocipede_s_000863.png to s3://sagemaker-ap-southeast-1-263436898058/test/velocipede_s_000863.png
# upload: test/velocipede_s_001699.png to s3://sagemaker-ap-southeast-1-263436898058/test/velocipede_s_001699.png
# upload: test/velocipede_s_001466.png to s3://sagemaker-ap-southeast-1-263436898058/test/velocipede_s_001466.png
# upload: test/velocipede_s_001277.png to s3://sagemaker-ap-southeast-1-263436898058/test/velocipede_s_001277.png
# upload: test/velocipede_s_001790.png to s3://sagemaker-ap-southeast-1-263436898058/test/velocipede_s_001790.png
# upload: test/velocipede_s_001744.png to s3://sagemaker-ap-southeast-1-263436898058/test/velocipede_s_001744.png

# %% [markdown]
# And that's it! You can check the bucket and verify that the items were uploaded.
#
# ## Model Training
#
# For Image Classification, Sagemaker [also expects metadata](https://docs.aws.amazon.com/sagemaker/latest/dg/image-classification.html) e.g. in the form of TSV files with labels and filepaths. We can generate these using our Pandas DataFrames from earlier:

# %%
def to_metadata_file(df, prefix):
    df["s3_path"] = df["filenames"]
    df["labels"] = df["labels"].apply(lambda x: 0 if x==8 else 1)
    return df[["row", "labels", "s3_path"]].to_csv(
        f"{prefix}.lst", sep="\t", index=False, header=False
    )
    
to_metadata_file(df_train.copy(), "train")
to_metadata_file(df_test.copy(), "test")

# %% [markdown]
# We can also upload our manifest files:

# %%
import boto3

# Upload files
boto3.Session().resource('s3').Bucket(
    bucket).Object('train.lst').upload_file('./train.lst')
boto3.Session().resource('s3').Bucket(
    bucket).Object('test.lst').upload_file('./test.lst')

# %% [markdown]
# Using the `bucket` and `region` info we can get the latest prebuilt container to run our training job, and define an output location on our s3 bucket for the model. Use the `image_uris` function from the SageMaker SDK to retrieve the latest `image-classification` image below:

# %%
# Use the image_uris function to retrieve the latest 'image-classification' image 
algo_image = sagemaker.image_uris.retrieve(framework="image-classification", region=region, version="latest")
s3_output_location = f"s3://{bucket}/models/image_model"
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: latest.

# %% [markdown]
# We're ready to create an estimator! Create an estimator `img_classifier_model` that uses one instance of `ml.p2.xlarge`. Ensure that y ou use the output location we defined above - we'll be referring to that later!

# %%
# Reference:
# https://sagemaker.readthedocs.io/en/stable/api/training/estimators.html
    
img_classifier_model=sagemaker.estimator.Estimator(
    algo_image,
    role,
    instance_count=1,
    instance_type="ml.p2.xlarge",
    output_path=s3_output_location,
    sagemaker_session=session
)

# %% [markdown]
# We can also set a few key hyperparameters and define the inputs for our model:

# %%
# img_classifier_model.set_hyperparameters(
#     image_shape='3,32,32', 
#     num_classes='2', 
#     num_training_samples= len(df_train)
# )


labelled_obj = [8, 48]
img_classifier_model.set_hyperparameters(
    image_shape="3,32,32",
    num_classes=str(len(labelled_obj)),
    num_training_samples=str(len(os.listdir('train'))),
    learning_rate=0.05,
    mini_batch_size=16
)

# %% [markdown]
# The `image-classification` image uses four input channels with very specific input parameters. For convenience, we've provided them below:

# %%
from sagemaker.debugger import Rule, rule_configs
from sagemaker.session import TrainingInput
model_inputs = {
        "train": sagemaker.inputs.TrainingInput(
            s3_data=f"s3://{bucket}/train/",
            content_type="application/x-image"
        ),
        "validation": sagemaker.inputs.TrainingInput(
            s3_data=f"s3://{bucket}/test/",
            content_type="application/x-image"
        ),
        "train_lst": sagemaker.inputs.TrainingInput(
            s3_data=f"s3://{bucket}/train.lst",
            content_type="application/x-image"
        ),
        "validation_lst": sagemaker.inputs.TrainingInput(
            s3_data=f"s3://{bucket}/test.lst",
            content_type="application/x-image"
        )
}

# %% [markdown]
# Great, now we can train the model using the model_inputs. In the cell below, call the `fit` method on our model,:

# %%
img_classifier_model.fit(model_inputs)
# Out:
# 2022-04-06 23:15:36 Starting - Starting the training job...
# 2022-04-06 23:16:01 Starting - Preparing the instances for trainingProfilerReport-1649286935: InProgress
# .........
# 2022-04-06 23:17:30 Downloading - Downloading input data......
# 2022-04-06 23:18:30 Training - Downloading the training image........Docker entrypoint called with argument(s): train
#
# 2022-04-06 23:19:51 Training - Training image download completed. Training in progress.[04/06/2022 23:19:53 INFO 140191539521344] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/image_classification/default-input.json: {'use_pretrained_model': 0, 'num_layers': 152, 'epochs': 30, 'learning_rate': 0.1, 'lr_scheduler_factor': 0.1, 'optimizer': 'sgd', 'momentum': 0, 'weight_decay': 0.0001, 'beta_1': 0.9, 'beta_2': 0.999, 'eps': 1e-08, 'gamma': 0.9, 'mini_batch_size': 32, 'image_shape': '3,224,224', 'precision_dtype': 'float32'}
# [04/06/2022 23:19:53 INFO 140191539521344] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'image_shape': '3,32,32', 'learning_rate': '0.05', 'mini_batch_size': '16', 'num_classes': '2', 'num_training_samples': '1000'}
# [04/06/2022 23:19:53 INFO 140191539521344] Final configuration: {'use_pretrained_model': 0, 'num_layers': 152, 'epochs': 30, 'learning_rate': '0.05', 'lr_scheduler_factor': 0.1, 'optimizer': 'sgd', 'momentum': 0, 'weight_decay': 0.0001, 'beta_1': 0.9, 'beta_2': 0.999, 'eps': 1e-08, 'gamma': 0.9, 'mini_batch_size': '16', 'image_shape': '3,32,32', 'precision_dtype': 'float32', 'num_classes': '2', 'num_training_samples': '1000'}
# [04/06/2022 23:19:53 INFO 140191539521344] Searching for .lst files in /opt/ml/input/data/train_lst.
# [04/06/2022 23:19:53 INFO 140191539521344] Creating record files for train.lst
# [04/06/2022 23:19:54 INFO 140191539521344] Done creating record files...
# [04/06/2022 23:19:54 INFO 140191539521344] Searching for .lst files in /opt/ml/input/data/validation_lst.
# [04/06/2022 23:19:54 INFO 140191539521344] Creating record files for test.lst
# [04/06/2022 23:19:54 INFO 140191539521344] Done creating record files...
# [04/06/2022 23:19:54 INFO 140191539521344] use_pretrained_model: 0
# [04/06/2022 23:19:54 INFO 140191539521344] multi_label: 0
# [04/06/2022 23:19:54 INFO 140191539521344] Performing random weight initialization
# [04/06/2022 23:19:54 INFO 140191539521344] ---- Parameters ----
# [04/06/2022 23:19:54 INFO 140191539521344] num_layers: 152
# [04/06/2022 23:19:54 INFO 140191539521344] data type: <class 'numpy.float32'>
# [04/06/2022 23:19:54 INFO 140191539521344] epochs: 30
# [04/06/2022 23:19:54 INFO 140191539521344] optimizer: sgd
# [04/06/2022 23:19:54 INFO 140191539521344] momentum: 0.9
# [04/06/2022 23:19:54 INFO 140191539521344] weight_decay: 0.0001
# [04/06/2022 23:19:54 INFO 140191539521344] learning_rate: 0.05
# [04/06/2022 23:19:54 INFO 140191539521344] num_training_samples: 1000
# [04/06/2022 23:19:54 INFO 140191539521344] mini_batch_size: 16
# [04/06/2022 23:19:54 INFO 140191539521344] image_shape: 3,32,32
# [04/06/2022 23:19:54 INFO 140191539521344] num_classes: 2
# [04/06/2022 23:19:54 INFO 140191539521344] augmentation_type: None
# [04/06/2022 23:19:54 INFO 140191539521344] kv_store: device
# [04/06/2022 23:19:54 INFO 140191539521344] checkpoint_frequency not set, will store the best model
# [04/06/2022 23:19:54 INFO 140191539521344] --------------------
# [04/06/2022 23:19:54 INFO 140191539521344] Setting number of threads: 3
# [23:20:03] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.3.x_ecl_Cuda_10.1.x.11282.0/AL2_x86_64/generic-flavor/src/src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (setting env variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [04/06/2022 23:20:20 INFO 140191539521344] Epoch[0] Batch [20]#011Speed: 18.951 samples/sec#011accuracy=0.541667
# [04/06/2022 23:20:27 INFO 140191539521344] Epoch[0] Batch [40]#011Speed: 27.026 samples/sec#011accuracy=0.528963
# [04/06/2022 23:20:33 INFO 140191539521344] Epoch[0] Batch [60]#011Speed: 31.458 samples/sec#011accuracy=0.566598
# [04/06/2022 23:20:34 INFO 140191539521344] Epoch[0] Train-accuracy=0.567540
# [04/06/2022 23:20:34 INFO 140191539521344] Epoch[0] Time cost=30.859
# [04/06/2022 23:20:35 INFO 140191539521344] Epoch[0] Validation-accuracy=0.708333
# [04/06/2022 23:20:36 INFO 140191539521344] Storing the best model with validation accuracy: 0.708333
# [04/06/2022 23:20:36 INFO 140191539521344] Saved checkpoint to "/opt/ml/model/image-classification-0001.params"
# [04/06/2022 23:20:43 INFO 140191539521344] Epoch[1] Batch [20]#011Speed: 46.042 samples/sec#011accuracy=0.622024
# [04/06/2022 23:20:50 INFO 140191539521344] Epoch[1] Batch [40]#011Speed: 46.342 samples/sec#011accuracy=0.660061
# [04/06/2022 23:20:57 INFO 140191539521344] Epoch[1] Batch [60]#011Speed: 46.500 samples/sec#011accuracy=0.661885
# [04/06/2022 23:20:57 INFO 140191539521344] Epoch[1] Train-accuracy=0.662298
# [04/06/2022 23:20:57 INFO 140191539521344] Epoch[1] Time cost=20.990
# [04/06/2022 23:20:59 INFO 140191539521344] Epoch[1] Validation-accuracy=0.778846
# [04/06/2022 23:20:59 INFO 140191539521344] Storing the best model with validation accuracy: 0.778846
# [04/06/2022 23:21:00 INFO 140191539521344] Saved checkpoint to "/opt/ml/model/image-classification-0002.params"
# [04/06/2022 23:21:07 INFO 140191539521344] Epoch[2] Batch [20]#011Speed: 44.194 samples/sec#011accuracy=0.684524
# [04/06/2022 23:29:35 INFO 140191539521344] Epoch[23] Batch [60]#011Speed: 45.179 samples/sec#011accuracy=0.974385
# [04/06/2022 23:29:36 INFO 140191539521344] Epoch[23] Train-accuracy=0.973790
# [04/06/2022 23:29:36 INFO 140191539521344] Epoch[23] Time cost=21.604
# [04/06/2022 23:29:37 INFO 140191539521344] Epoch[23] Validation-accuracy=0.798077
# [04/06/2022 23:29:45 INFO 140191539521344] Epoch[24] Batch [20]#011Speed: 44.562 samples/sec#011accuracy=0.946429
# [04/06/2022 23:29:52 INFO 140191539521344] Epoch[24] Batch [40]#011Speed: 45.048 samples/sec#011accuracy=0.954268
# [04/06/2022 23:29:59 INFO 140191539521344] Epoch[24] Batch [60]#011Speed: 45.219 samples/sec#011accuracy=0.960041
# [04/06/2022 23:30:00 INFO 140191539521344] Epoch[24] Train-accuracy=0.960685
# [04/06/2022 23:30:00 INFO 140191539521344] Epoch[24] Time cost=21.577
# [04/06/2022 23:30:01 INFO 140191539521344] Epoch[24] Validation-accuracy=0.843750
# [04/06/2022 23:30:10 INFO 140191539521344] Epoch[25] Batch [20]#011Speed: 43.820 samples/sec#011accuracy=0.967262
# [04/06/2022 23:30:17 INFO 140191539521344] Epoch[25] Batch [40]#011Speed: 44.602 samples/sec#011accuracy=0.955793
# [04/06/2022 23:30:25 INFO 140191539521344] Epoch[25] Batch [60]#011Speed: 43.174 samples/sec#011accuracy=0.961066
# [04/06/2022 23:30:25 INFO 140191539521344] Epoch[25] Train-accuracy=0.961694
# [04/06/2022 23:30:25 INFO 140191539521344] Epoch[25] Time cost=22.594
# [04/06/2022 23:30:27 INFO 140191539521344] Epoch[25] Validation-accuracy=0.855769
# [04/06/2022 23:30:27 INFO 140191539521344] Storing the best model with validation accuracy: 0.855769
# [04/06/2022 23:30:28 INFO 140191539521344] Saved checkpoint to "/opt/ml/model/image-classification-0026.params"
# [04/06/2022 23:30:35 INFO 140191539521344] Epoch[26] Batch [20]#011Speed: 43.100 samples/sec#011accuracy=0.961310
# [04/06/2022 23:30:43 INFO 140191539521344] Epoch[26] Batch [40]#011Speed: 42.535 samples/sec#011accuracy=0.961890
# [04/06/2022 23:30:51 INFO 140191539521344] Epoch[26] Batch [60]#011Speed: 41.706 samples/sec#011accuracy=0.959016
# [04/06/2022 23:30:51 INFO 140191539521344] Epoch[26] Train-accuracy=0.959677
# [04/06/2022 23:30:51 INFO 140191539521344] Epoch[26] Time cost=23.368
# [04/06/2022 23:30:52 INFO 140191539521344] Epoch[26] Validation-accuracy=0.802083
# [04/06/2022 23:31:00 INFO 140191539521344] Epoch[27] Batch [20]#011Speed: 44.683 samples/sec#011accuracy=0.970238
# [04/06/2022 23:31:08 INFO 140191539521344] Epoch[27] Batch [40]#011Speed: 44.455 samples/sec#011accuracy=0.977134
# [04/06/2022 23:31:14 INFO 140191539521344] Epoch[27] Batch [60]#011Speed: 45.141 samples/sec#011accuracy=0.979508
# [04/06/2022 23:31:15 INFO 140191539521344] Epoch[27] Train-accuracy=0.979839
# [04/06/2022 23:31:15 INFO 140191539521344] Epoch[27] Time cost=21.609
# [04/06/2022 23:31:16 INFO 140191539521344] Epoch[27] Validation-accuracy=0.841346
# [04/06/2022 23:31:24 INFO 140191539521344] Epoch[28] Batch [20]#011Speed: 45.683 samples/sec#011accuracy=0.985119
# [04/06/2022 23:31:31 INFO 140191539521344] Epoch[28] Batch [40]#011Speed: 46.229 samples/sec#011accuracy=0.986280
# [04/06/2022 23:31:38 INFO 140191539521344] Epoch[28] Batch [60]#011Speed: 46.487 samples/sec#011accuracy=0.989754
# [04/06/2022 23:31:38 INFO 140191539521344] Epoch[28] Train-accuracy=0.989919
# [04/06/2022 23:31:38 INFO 140191539521344] Epoch[28] Time cost=20.992
# [04/06/2022 23:31:39 INFO 140191539521344] Epoch[28] Validation-accuracy=0.848958
# [04/06/2022 23:31:47 INFO 140191539521344] Epoch[29] Batch [20]#011Speed: 45.840 samples/sec#011accuracy=0.994048
# [04/06/2022 23:31:54 INFO 140191539521344] Epoch[29] Batch [40]#011Speed: 46.352 samples/sec#011accuracy=0.995427
# [04/06/2022 23:32:01 INFO 140191539521344] Epoch[29] Batch [60]#011Speed: 46.473 samples/sec#011accuracy=0.996926
# [04/06/2022 23:32:01 INFO 140191539521344] Epoch[29] Train-accuracy=0.996976
# [04/06/2022 23:32:01 INFO 140191539521344] Epoch[29] Time cost=21.002
# [04/06/2022 23:32:03 INFO 140191539521344] Epoch[29] Validation-accuracy=0.836538
#
# 2022-04-06 23:32:10 Uploading - Uploading generated training model
# 2022-04-06 23:33:02 Completed - Training job completed
# ProfilerReport-1649286935: IssuesFound
# Training seconds: 923
# Billable seconds: 923

# %% [markdown]
# If all goes well, you'll end up with a model topping out above `.8` validation accuracy. With only 1000 training samples in the CIFAR dataset, that's pretty good. We could definitely pursue data augmentation & gathering more samples to help us improve further, but for now let's proceed to deploy our model.
#
# ### Getting ready to deploy
#
# To begin with, let's configure Model Monitor to track our deployment. We'll define a `DataCaptureConfig` below:

# %%
from sagemaker.model_monitor import DataCaptureConfig

data_capture_config = DataCaptureConfig(
    enable_capture=True,
    sampling_percentage=100,
    destination_s3_uri=f"s3://{bucket}/data_capture",
    sagemaker_session=session,
)

# %% [markdown]
# Note the `destination_s3_uri` parameter: At the end of the project, we can explore the `data_capture` directory in S3 to find crucial data about the inputs and outputs Model Monitor has observed on our model endpoint over time.
#
# With that done, deploy your model on a single `ml.m5.xlarge` instance with the data capture config attached:

# %%
from time import gmtime, strftime

# timestamp = strftime("%Y-%m-%d %H:%M:%S", gmtime())
timestamp = strftime("%Y-%m-%d", gmtime())
endpoint_name = f"scones-bicycle-motorcycle-classifier-{timestamp}"

deployment = img_classifier_model.deploy(
    initial_instance_count=1,
    instance_type='ml.m5.xlarge',
    data_capture_config=data_capture_config,
    endpoint_name=endpoint_name
)

endpoint = deployment.endpoint_name
print(endpoint)
# Out:
# ---------------!scones-bicycle-motorcycle-classifier-2022-04-07

# %% [markdown]
# Note the endpoint name for later as well.
#
# Next, instantiate a Predictor:

# %%
from sagemaker.predictor import Predictor

predictor = Predictor(
    endpoint_name = endpoint,
    sagemaker_session = session
)

# %% [markdown]
# In the code snippet below we are going to prepare one of your saved images for prediction. Use the predictor to process the `payload`.

# %%
from sagemaker.serializers import IdentitySerializer
import base64

predictor.serializer = IdentitySerializer("image/png")
with open("./test/bicycle_s_001789.png", "rb") as f:
    payload = f.read()

# %%
inference = predictor.predict(payload)

# %% [markdown]
# Your `inference` object is an array of two values, the predicted probability value for each of your classes (bicycle and motorcycle respectively.) So, for example, a value of `b'[0.91, 0.09]'` indicates the probability of being a bike is 91% and being a motorcycle is 9%.

# %%
print(inference)
# Out:
# b'[0.9992095232009888, 0.0007903929799795151]'

# %%
print(inference)
# Out:
# b'[0.008231261745095253, 0.9917687177658081]'

# %%
filePath = './test/'
image_arr = os.listdir(filePath)


for i in image_arr:
    cur_file = f'./test/{i}'
    with open(cur_file, "rb") as f:
        payload = f.read()
        inference = predictor.predict(payload)
        print(i, inference)
# Out:
# motorbike_s_000135.png b'[0.008231261745095253, 0.9917687177658081]'
# bicycle_s_001107.png b'[0.9907989501953125, 0.009201028384268284]'
# motorcycle_s_001348.png b'[0.0003992460551671684, 0.9996008276939392]'
# bicycle_s_001047.png b'[0.24678407609462738, 0.7532159090042114]'
# safety_bicycle_s_001153.png b'[0.22941873967647552, 0.7705813050270081]'
# motorcycle_s_000352.png b'[1.4199360975908348e-07, 0.9999998807907104]'
# motorbike_s_000126.png b'[0.8405784368515015, 0.15942153334617615]'
# motorcycle_s_001519.png b'[0.034547120332717896, 0.9654529094696045]'
# safety_bike_s_000699.png b'[0.9984367489814758, 0.0015632914146408439]'
# bicycle_s_001102.png b'[0.9999065399169922, 9.350154869025573e-05]'
# velocipede_s_001335.png b'[0.9999934434890747, 6.537487479363335e-06]'
# bicycle_s_000513.png b'[0.9999551773071289, 4.479528433876112e-05]'
# velocipede_s_000001.png b'[0.9987389445304871, 0.0012611036654561758]'
# bicycle_s_000977.png b'[0.9994903802871704, 0.0005096413660794497]'
# motorcycle_s_000427.png b'[6.723653456219836e-08, 0.9999998807907104]'
# bicycle_s_000030.png b'[0.9958797693252563, 0.004120186436921358]'
# trail_bike_s_000073.png b'[0.0002221427421318367, 0.9997778534889221]'
# minibike_s_000052.png b'[4.670373891713098e-05, 0.9999532699584961]'
# motorbike_s_000005.png b'[0.0003261042002122849, 0.9996739625930786]'
# motorcycle_s_000878.png b'[0.20560909807682037, 0.794390857219696]'
# moped_s_000306.png b'[0.016522753983736038, 0.9834772944450378]'
# minibike_s_000828.png b'[0.8164422512054443, 0.1835576891899109]'
# velocipede_s_000863.png b'[0.9994644522666931, 0.0005355824832804501]'
# cycle_s_001297.png b'[0.9858492612838745, 0.014150703325867653]'
# cycle_s_001915.png b'[0.8855897188186646, 0.11441025882959366]'
# minibike_s_000792.png b'[0.06554242968559265, 0.9344576001167297]'
# motorcycle_s_000007.png b'[1.2800883882960732e-15, 1.0]'
# safety_bicycle_s_001322.png b'[0.9998213648796082, 0.00017869984731078148]'
# velocipede_s_001232.png b'[0.9999995231628418, 5.084427243673417e-07]'
# minibike_s_000947.png b'[0.018721776083111763, 0.9812782406806946]'
# motorcycle_s_000963.png b'[1.525052192819995e-13, 1.0]'
# bike_s_002009.png b'[0.9998373985290527, 0.00016256920935120434]'
# moped_s_000007.png b'[2.2299731426755898e-05, 0.999977707862854]'
# motorcycle_s_000530.png b'[0.00015246696420945227, 0.9998475313186646]'
# minibike_s_001732.png b'[0.00017763722280506045, 0.9998224377632141]'
# bike_s_001852.png b'[0.9946528673171997, 0.005347149912267923]'
# motorcycle_s_000485.png b'[0.005635411944240332, 0.9943646192550659]'
# ordinary_bicycle_s_000105.png b'[0.9999890327453613, 1.0953332093777135e-05]'
# motorcycle_s_001687.png b'[4.329486769094615e-10, 1.0]'
# bike_s_002208.png b'[0.42731374502182007, 0.5726862549781799]'
# minibike_s_002227.png b'[0.9974393844604492, 0.0025605992414057255]'
# motorcycle_s_000139.png b'[6.231881122253924e-10, 1.0]'
# motorcycle_s_000323.png b'[0.9120014905929565, 0.08799847960472107]'
# motorbike_s_000121.png b'[0.17110061645507812, 0.8288994431495667]'
# velocipede_s_001790.png b'[0.9990025162696838, 0.000997448805719614]'
# velocipede_s_000292.png b'[0.9999734163284302, 2.6554027499514632e-05]'
# motorcycle_s_000512.png b'[3.223150357722915e-10, 1.0]'
# motorcycle_s_000446.png b'[0.00023478813818655908, 0.9997652173042297]'
# bike_s_000330.png b'[0.9555764198303223, 0.04442360997200012]'
# bike_s_000487.png b'[0.998822033405304, 0.0011779952328652143]'
# motorcycle_s_000211.png b'[0.06947997957468033, 0.9305199980735779]'
# minibike_s_000573.png b'[0.00027893739752471447, 0.9997209906578064]'
# minibike_s_001473.png b'[1.4415487692431839e-09, 1.0]'
# cycle_s_001306.png b'[0.9977056384086609, 0.0022943441290408373]'
# bicycle_s_002458.png b'[0.9511316418647766, 0.04886834695935249]'
# safety_bike_s_000541.png b'[0.9943349957466125, 0.005664990749210119]'
# bicycle_s_000479.png b'[0.9275038242340088, 0.07249613851308823]'
# safety_bike_s_000540.png b'[0.03249209374189377, 0.9675078988075256]'
# safety_bike_s_000488.png b'[0.9998548030853271, 0.00014512769121211022]'
# bike_s_001738.png b'[0.9919407963752747, 0.008059242740273476]'
# minibike_s_002173.png b'[4.563758920994587e-06, 0.9999954700469971]'
# safety_bike_s_001481.png b'[0.9992302656173706, 0.0007697311230003834]'
# safety_bike_s_000192.png b'[0.2403751164674759, 0.7596248388290405]'
# motorbike_s_000465.png b'[0.9790233373641968, 0.020976604893803596]'
# velocipede_s_001355.png b'[0.9878044128417969, 0.012195557355880737]'
# velocipede_s_001633.png b'[0.9999955892562866, 4.388505658425856e-06]'
# bicycle_s_000777.png b'[0.9999995231628418, 4.7428875404875726e-07]'
# minibike_s_000075.png b'[0.0005749261472374201, 0.9994250535964966]'
# minibike_s_000290.png b'[0.0002789634745568037, 0.9997209906578064]'
# velocipede_s_000041.png b'[0.9999651908874512, 3.481629028101452e-05]'
# motorcycle_s_001385.png b'[0.0027653896249830723, 0.9972346425056458]'
# ordinary_bicycle_s_000113.png b'[0.9998257756233215, 0.0001742807507980615]'
# velocipede_s_000369.png b'[0.9457168579101562, 0.05428313463926315]'
# minibike_s_001441.png b'[4.6128528197186824e-07, 0.9999995231628418]'
# minibike_s_001547.png b'[0.23774538934230804, 0.7622545957565308]'
# motorcycle_s_000602.png b'[0.014932600781321526, 0.9850673675537109]'
# motorcycle_s_001960.png b'[1.0087256896440522e-06, 0.9999990463256836]'
# minibike_s_000913.png b'[0.000509242934640497, 0.9994907379150391]'
# motorbike_s_000333.png b'[0.07314421981573105, 0.926855742931366]'
# motorcycle_s_000797.png b'[0.7770756483078003, 0.2229243367910385]'
# motorcycle_s_001269.png b'[0.0001266260223928839, 0.9998733997344971]'
# cycle_s_002613.png b'[0.9997829794883728, 0.00021702380036003888]'
# minibike_s_000254.png b'[9.148484991783334e-08, 0.9999998807907104]'
# minibike_s_001867.png b'[5.055226574768312e-05, 0.9999494552612305]'
# motorcycle_s_001906.png b'[1.82306975071711e-10, 1.0]'
# motorcycle_s_001508.png b'[1.2376639460853767e-05, 0.9999876022338867]'
# motorcycle_s_000825.png b'[0.003788954811170697, 0.996211051940918]'
# motorcycle_s_000040.png b'[0.00028214597841724753, 0.9997178912162781]'
# bike_s_000694.png b'[0.9990984201431274, 0.0009016134426929057]'
# minibike_s_000801.png b'[0.012717043980956078, 0.9872829914093018]'
# bike_s_001068.png b'[0.9972742199897766, 0.002725810743868351]'
# motorcycle_s_000141.png b'[0.1161867007613182, 0.8838133215904236]'
# minibike_s_000880.png b'[0.9873508810997009, 0.01264912262558937]'
# bike_s_000071.png b'[0.9987084865570068, 0.0012915024999529123]'
# safety_bicycle_s_001286.png b'[0.992213785648346, 0.007786237169057131]'
# ordinary_bicycle_s_000431.png b'[0.9999362230300903, 6.382805440807715e-05]'
# motorcycle_s_002026.png b'[2.780831391980404e-13, 1.0]'
# bike_s_000941.png b'[0.9946327209472656, 0.005367319565266371]'
# safety_bike_s_001132.png b'[0.9992738366127014, 0.000726132420822978]'
# motorcycle_s_001782.png b'[6.280665765245885e-09, 1.0]'
# velocipede_s_001277.png b'[0.9997829794883728, 0.00021706581173930317]'
# motorcycle_s_000679.png b'[0.019077474251389503, 0.980922520160675]'
# ordinary_bicycle_s_000169.png b'[0.9998873472213745, 0.00011264818749623373]'
# bicycle_s_000779.png b'[0.999947190284729, 5.2842362492810935e-05]'
# velocipede_s_000106.png b'[0.9997861981391907, 0.00021378518431447446]'
# safety_bike_s_001088.png b'[0.9985765218734741, 0.0014234225964173675]'
# velocipede_s_001466.png b'[0.9997450709342957, 0.00025497094611637294]'
# bicycle_s_000776.png b'[0.9999992847442627, 7.65043751016492e-07]'
# motorcycle_s_000494.png b'[6.834539334477086e-08, 0.9999998807907104]'
# minibike_s_000309.png b'[3.864142399834236e-06, 0.9999961853027344]'
# bike_s_001342.png b'[0.870503306388855, 0.12949666380882263]'
# motorcycle_s_001971.png b'[7.926843892391844e-08, 0.9999998807907104]'
# cycle_s_001044.png b'[0.9850384593009949, 0.014961612410843372]'
# cycle_s_001214.png b'[0.18518999218940735, 0.8148099780082703]'
# safety_bicycle_s_000280.png b'[0.9999877214431763, 1.2221638826304115e-05]'
# motorcycle_s_000060.png b'[0.0016414085403084755, 0.9983585476875305]'
# bike_s_001784.png b'[0.7151839733123779, 0.28481602668762207]'
# motorcycle_s_001249.png b'[0.025681519880890846, 0.9743184447288513]'
# cycle_s_000010.png b'[0.9662178754806519, 0.03378209471702576]'
# cycle_s_001648.png b'[0.9917227625846863, 0.008277240209281445]'
# minibike_s_001089.png b'[1.0757302106867428e-06, 0.999998927116394]'
# ordinary_bicycle_s_000284.png b'[0.9996922016143799, 0.00030783991678617895]'
# motorcycle_s_001936.png b'[0.9974767565727234, 0.002523221308365464]'
# minibike_s_000055.png b'[2.3836774332153254e-08, 1.0]'
# bike_s_002116.png b'[0.9999988079071045, 1.1433332929300377e-06]'
# minibike_s_000505.png b'[6.404530950021581e-07, 0.9999994039535522]'
# velocipede_s_001744.png b'[0.006991810165345669, 0.9930081367492676]'
# bicycle_s_000031.png b'[0.999991774559021, 8.173342394002248e-06]'
# motorbike_s_000629.png b'[1.5393488865811378e-05, 0.999984622001648]'
# motorcycle_s_000876.png b'[0.0020698898006230593, 0.9979300498962402]'
# safety_bicycle_s_001575.png b'[0.9990936517715454, 0.0009064102778211236]'
# bike_s_001216.png b'[0.807091474533081, 0.19290846586227417]'
# motorcycle_s_001164.png b'[2.6290621235602885e-07, 0.9999997615814209]'
# bike_s_000457.png b'[0.9999829530715942, 1.7101687262766063e-05]'
# motorcycle_s_000739.png b'[6.8257331804488786e-06, 0.9999932050704956]'
# cycle_s_000970.png b'[0.9840925931930542, 0.015907421708106995]'
# motorbike_s_000324.png b'[0.9987640380859375, 0.0012359963729977608]'
# bike_s_001073.png b'[0.9999903440475464, 9.666422556620091e-06]'
# motorcycle_s_002126.png b'[0.9164208173751831, 0.08357923477888107]'
# motorcycle_s_000866.png b'[0.00025272369384765625, 0.9997472167015076]'
# bike_s_000041.png b'[4.897444523521699e-05, 0.9999510049819946]'
# motorcycle_s_000222.png b'[0.0046591549180448055, 0.9953408241271973]'
# safety_bike_s_001065.png b'[0.999976634979248, 2.3332322598434985e-05]'
# cycle_s_000068.png b'[0.9778919219970703, 0.022108159959316254]'
# safety_bike_s_001253.png b'[0.9988383650779724, 0.001161704771220684]'
# dirt_bike_s_000001.png b'[5.938590220466722e-06, 0.9999940395355225]'
# motorcycle_s_001955.png b'[2.515580632689307e-09, 1.0]'
# cycle_s_002661.png b'[0.9708659648895264, 0.029134061187505722]'
# motorcycle_s_002112.png b'[2.2991494819102343e-10, 1.0]'
# moped_s_000064.png b'[0.035671643912792206, 0.9643282890319824]'
# minibike_s_002230.png b'[1.906123592299025e-10, 1.0]'
# minibike_s_000960.png b'[2.1634244742885222e-11, 1.0]'
# cycle_s_002964.png b'[0.04850900545716286, 0.9514909982681274]'
# motorcycle_s_001261.png b'[0.014064195565879345, 0.9859358072280884]'
# motorcycle_s_000450.png b'[0.0005982318543829024, 0.9994018077850342]'
# ordinary_bicycle_s_000437.png b'[0.9986502528190613, 0.0013497639447450638]'
# motorcycle_s_000171.png b'[0.8403438329696655, 0.1596561223268509]'
# bicycle_s_001804.png b'[0.9897776246070862, 0.010222326964139938]'
# bicycle_s_002735.png b'[0.7257367968559265, 0.2742632329463959]'
# safety_bicycle_s_000235.png b'[0.9998935461044312, 0.00010642490815371275]'
# bicycle_s_000059.png b'[0.010294678620994091, 0.9897053837776184]'
# ordinary_bicycle_s_000350.png b'[0.9850843548774719, 0.014915664680302143]'
# safety_bicycle_s_000315.png b'[0.6710306406021118, 0.3289693593978882]'
# safety_bike_s_001690.png b'[0.004950684029608965, 0.9950492978096008]'
# bicycle_s_001218.png b'[0.9858932495117188, 0.014106781221926212]'
# motorcycle_s_002177.png b'[3.034369422394434e-09, 1.0]'
# minibike_s_001605.png b'[0.0010377304861322045, 0.9989622831344604]'
# velocipede_s_001699.png b'[0.9479228258132935, 0.052077218890190125]'
# motorcycle_s_001679.png b'[0.35354283452033997, 0.6464571952819824]'
# safety_bike_s_000390.png b'[0.9832773208618164, 0.016722727566957474]'
# motorcycle_s_000606.png b'[1.7435049237679578e-10, 1.0]'
# motorcycle_s_000063.png b'[0.011854891665279865, 0.988145112991333]'
# velocipede_s_001201.png b'[0.999700665473938, 0.00029940190142951906]'
# moped_s_000033.png b'[0.02240811474621296, 0.9775918126106262]'
# motorbike_s_000433.png b'[0.7242588400840759, 0.2757411003112793]'
# bicycle_s_001789.png b'[0.9992095232009888, 0.0007903929799795151]'
# cycle_s_001953.png b'[0.9512118697166443, 0.04878811165690422]'
# cycle_s_002305.png b'[0.8769632577896118, 0.1230367124080658]'
# minibike_s_001893.png b'[9.121614574780779e-09, 1.0]'
# safety_bike_s_000791.png b'[0.9995566010475159, 0.00044340567546896636]'
# motorcycle_s_000685.png b'[0.004524074494838715, 0.9954759478569031]'
# bike_s_000801.png b'[0.9994434714317322, 0.0005565528990700841]'
# bike_s_001159.png b'[0.17583023011684418, 0.8241697549819946]'
# minibike_s_000398.png b'[3.402859993784091e-09, 1.0]'
# motorcycle_s_000049.png b'[0.0001450953132007271, 0.9998549222946167]'
# bike_s_000131.png b'[0.9996294975280762, 0.00037046708166599274]'
# velocipede_s_001379.png b'[2.723871375565068e-06, 0.9999972581863403]'
# safety_bike_s_001087.png b'[0.9958482980728149, 0.004151712637394667]'
# motorcycle_s_000615.png b'[0.003266491461545229, 0.996733546257019]'
# bike_s_000658.png b'[0.10612949728965759, 0.89387047290802]'
# minibike_s_001651.png b'[5.10771599238069e-07, 0.9999995231628418]'
# minibike_s_000288.png b'[0.00021242140792310238, 0.9997876286506653]'
# ordinary_bicycle_s_000158.png b'[0.9999518394470215, 4.817260196432471e-05]'
# bike_s_000643.png b'[0.9999849796295166, 1.497405355621595e-05]'
# safety_bike_s_000438.png b'[0.9988969564437866, 0.0011030319146811962]'
# minibike_s_002051.png b'[2.2111217390374804e-07, 0.9999997615814209]'
# motorcycle_s_000042.png b'[0.22572122514247894, 0.7742787599563599]'
# bike_s_000163.png b'[0.1970607042312622, 0.8029392957687378]'
# minibike_s_000497.png b'[0.9699969291687012, 0.030003070831298828]'
# motorcycle_s_001892.png b'[0.08719310164451599, 0.9128069281578064]'

# %% [markdown]
# ### Draft Lambdas and Step Function Workflow
#
# Your operations team uses Step Functions to orchestrate serverless workflows. One of the nice things about Step Functions is that [workflows can call other workflows](https://docs.aws.amazon.com/step-functions/latest/dg/connect-stepfunctions.html), so the team can easily plug your workflow into the broader production architecture for Scones Unlimited.
#
# In this next stage you're going to write and deploy three Lambda functions, and then use the Step Functions visual editor to chain them together! Our functions are going to work with a simple data object:
#
# ```python
# {
#     "inferences": [], # Output of predictor.predict
#     "s3_key": "", # Source data S3 key
#     "s3_bucket": "", # Source data S3 bucket
#     "image_data": ""  # base64 encoded string containing the image data
# }
# ```
#
# A good test object that you can use for Lambda tests and Step Function executions, throughout the next section, might look like this:
#
# ```python
# {
#   "image_data": "",
#   "s3_bucket": MY_BUCKET_NAME, # Fill in with your bucket
#   "s3_key": "test/bicycle_s_000513.png"
# }
# ```
#
# Using these fields, your functions can read and write the necessary data to execute your workflow. Let's start with the first function. Your first Lambda function will copy an object from S3, base64 encode it, and then return it to the step function as `image_data` in an event.
#
# Go to the Lambda dashboard and create a new Lambda function with a descriptive name like "serializeImageData" and select thr 'Python 3.8' runtime. Add the same permissions as the SageMaker role you created earlier. (Reminder: you do this in the Configuration tab under "Permissions"). Once you're ready, use the starter code below to craft your Lambda handler:
#
# ```python
# import json
# import boto3
# import base64
#
# s3 = boto3.client('s3')
#
# def lambda_handler(event, context):
#     """A function to serialize target data from S3"""
#
#     # Get the s3 address from the Step Function event input
#     key = ## TODO: fill in
#     bucket = ## TODO: fill in
#
#     # Download the data from s3 to /tmp/image.png
#     ## TODO: fill in
#
#     # We read the data from a file
#     with open("/tmp/image.png", "rb") as f:
#         image_data = base64.b64encode(f.read())
#
#     # Pass the data back to the Step Function
#     print("Event:", event.keys())
#     return {
#         'statusCode': 200,
#         'body': {
#             "image_data": image_data,
#             "s3_bucket": bucket,
#             "s3_key": key,
#             "inferences": []
#         }
#     }
# ```
#
# The next function is responsible for the classification part - we're going to take the image output from the previous function, decode it, and then pass inferences back to the the Step Function.
#
# Because this Lambda will have runtime dependencies (i.e. the SageMaker SDK) you'll need to package them in your function. *Key reading:* https://docs.aws.amazon.com/lambda/latest/dg/python-package-create.html#python-package-create-with-dependency
#
# Create a new Lambda function with the same rights and a descriptive name, then fill in the starter code below for your classifier Lambda.
#
# ```python
# import json
# import sagemaker
# import base64
# from sagemaker.serializers import IdentitySerializer
#
# # Fill this in with the name of your deployed model
# ENDPOINT = ## TODO: fill in
#
# def lambda_handler(event, context):
#
#     # Decode the image data
#     image = base64.b64decode(## TODO: fill in)
#
#     # Instantiate a Predictor
#     predictor = ## TODO: fill in
#
#     # For this model the IdentitySerializer needs to be "image/png"
#     predictor.serializer = IdentitySerializer("image/png")
#
#     # Make a prediction:
#     inferences = ## TODO: fill in
#
#     # We return the data back to the Step Function
#     event["inferences"] = inferences.decode('utf-8')
#     return {
#         'statusCode': 200,
#         'body': json.dumps(event)
#     }
# ```
#
# Finally, we need to filter low-confidence inferences. Define a threshold between 1.00 and 0.000 for your model: what is reasonble for you? If the model predicts at `.70` for it's highest confidence label, do we want to pass that inference along to downstream systems? Make one last Lambda function and tee up the same permissions:
#
# ```python
# import json
#
#
# THRESHOLD = .93
#
#
# def lambda_handler(event, context):
#
#     # Grab the inferences from the event
#     inferences = ## TODO: fill in
#
#     # Check if any values in our inferences are above THRESHOLD
#     meets_threshold = ## TODO: fill in
#
#     # If our threshold is met, pass our data back out of the
#     # Step Function, else, end the Step Function with an error
#     if meets_threshold:
#         pass
#     else:
#         raise("THRESHOLD_CONFIDENCE_NOT_MET")
#
#     return {
#         'statusCode': 200,
#         'body': json.dumps(event)
#     }
# ```
# Once you have tested the lambda functions, save the code for each lambda function in a python script called 'lambda.py'.
#
# With your lambdas in place, you can use the Step Functions visual editor to construct a workflow that chains them together. In the Step Functions console you'll have the option to author a Standard step function *Visually*.
#
# When the visual editor opens, you'll have many options to add transitions in your workflow. We're going to keep it simple and have just one: to invoke Lambda functions. Add three of them chained together. For each one, you'll be able to select the Lambda functions you just created in the proper order, filter inputs and outputs, and give them descriptive names.
#
# Make sure that you:
#
# 1. Are properly filtering the inputs and outputs of your invokations (e.g. `$.body`)
# 2. Take care to remove the error handling from the last function - it's supposed to "fail loudly" for your operations colleagues!
#
# Take a screenshot of your working step function in action and export the step function as JSON for your submission package.

# %% [markdown]
# Great! Now you can use the files in `./test` as test files for our workflow. Depending on our threshold, our workflow should reliably pass predictions about images from `./test` on to downstream systems, while erroring out for inferences below our confidence threshold!
#
# ### Testing and Evaluation
#
# Do several step function invokations using data from the `./test` folder. This process should give you confidence that the workflow both *succeeds* AND *fails* as expected. In addition, SageMaker Model Monitor will generate recordings of your data and inferences which we can visualize.
#
# Here's a function that can help you generate test inputs for your invokations:

# %%
import random
import boto3
import json


def generate_test_case():
    # Setup s3 in boto3
    s3 = boto3.resource('s3')
    
    bucket_obj = s3.Bucket(bucket)
    # Randomly pick from sfn or test folders in our bucket
    objects = bucket_obj.objects.all().filter(Prefix="test")
    
    # Grab any random object key from that folder!
    obj = random.choice([x.key for x in objects])
    
    return json.dumps({
        "image_data": "",
        "s3_bucket": bucket,
        "s3_key": obj
    })

test_case = generate_test_case()
print(test_case)
# Out:
# {"image_data": "", "s3_bucket": "sagemaker-ap-southeast-1-263436898058", "s3_key": "test/bike_s_000071.png"}

# %%
bucket
# Out:
# 'sagemaker-ap-southeast-1-263436898058'

# %% [markdown]
# In the Step Function dashboard for your new function, you can create new executions and copy in the generated test cases. Do several executions so that you can generate data you can evaluate and visualize.
#
# Once you've done several executions, let's visualize the record of our inferences. Pull in the JSONLines data from your inferences like so:

# %%
from datetime import date

# %%
time = date.today().strftime("%d-%b-%Y")
time
# Out:
# '07-Apr-2022'

# %%
from sagemaker.s3 import S3Downloader

# data captured on s3 will be saved into sagemaker
data_path = f's3://{bucket}/data_capture/'

S3Downloader.download(data_path, "captured_data")

# Feel free to repeat this multiple times and pull in more data

# %% [markdown]
# The data are in JSONLines format, where multiple valid JSON objects are stacked on top of eachother in a single `jsonl` file. We'll import an open-source library, `jsonlines` that was purpose built for parsing this format.

# %%
# !pip install jsonlines
import jsonlines
# Out:
# Collecting jsonlines
#   Downloading jsonlines-3.0.0-py3-none-any.whl (8.5 kB)
# Requirement already satisfied: typing-extensions in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from jsonlines) (3.10.0.0)
# Requirement already satisfied: attrs>=19.2.0 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from jsonlines) (20.3.0)
# Installing collected packages: jsonlines
# Successfully installed jsonlines-3.0.0

# %% [markdown]
# Now we can extract the data from each of the source files:

# %%
# import os

# # List the file names we downloaded
# file_handles = os.listdir("./captured_data")

# # Dump all the data into an array
# json_data = []
# for jsonl in file_handles:
#     with jsonlines.open(f"./captured_data/{jsonl}") as f:
#         json_data.append(f.read())

# %%
# the 'data_catupre' is a datetime-aware path with nested folders, need traverse to get all json files
# Dump all the data into an array
json_data=[]

def getallfile(path):
    allfilelist=os.listdir(path)
    for file in allfilelist:
        filepath=os.path.join(path,file)
        if os.path.isdir(filepath):
            getallfile(filepath)
        elif os.path.isfile(filepath):
            with jsonlines.open(filepath) as f:
                json_data.append(f.read())

getallfile("./captured_data")

# %% [markdown]
# The data should now be a list of dictionaries, with significant nesting. We'll give you an example of some code that grabs data out of the objects and visualizes it:

# %%
# Define how we'll get our data
def simple_getter(obj):
    inferences = obj["captureData"]["endpointOutput"]["data"]
    timestamp = obj["eventMetadata"]["inferenceTime"]
    return json.loads(inferences), timestamp

simple_getter(json_data[0])
# Out:
# ([0.24678407609462738, 0.7532159090042114], '2022-04-07T03:41:11Z')

# %% [markdown]
# Finally, here's an example of a visualization you can build with this data. In this last part, you will take some time and build your own - the captured data has the input images, the resulting inferences, and the timestamps.

# %%
a = [10,20,5]
a.index(max(a))
# Out:
# 1

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib.colors import ListedColormap
import io
import base64
import numpy as np
# Populate the data for the x and y axis
x = []
y = []
c_arr = []
for obj in json_data:
    inference, timestamp = simple_getter(obj)

    y.append(max(inference))
    x.append(timestamp)
    
    if max(inference) < 0.88:
        c_arr.append(0)
    else:
        if inference.index(max(inference)) == 0:
            c_arr.append(1)
        else:
            c_arr.append(2)
            
# Todo: here is an visualization example, take some time to build another visual that helps monitor the result
# Plot the data

labels = ['Exception', 'Bicycle', 'Motorcycle']
colors = ListedColormap(['r','b','g'])

scatter = plt.scatter(x, y, c=c_arr, cmap=colors)
plt.ylim(bottom=.70)

plt.legend(handles=scatter.legend_elements()[0], labels=labels)
# Add labels
plt.axhline(y=0.88, color='g', linestyle='--')
plt.ylabel("Confidence")
plt.suptitle("Observed Recent Inferences", size=14)
plt.title("Pictured with confidence threshold for production use", size=10)

# Give it some pizzaz!
plt.style.use("Solarize_Light2")
plt.gcf().autofmt_xdate()

# %%
print('Total predictions:', len(y))
print('Correct predictions:', sum([i > 0.88 for i in y]))
print('Exceptions:', sum([i < 0.88 for i in y]))
print('Bicycles:', sum([i == 1 for i in c_arr]))
print('Motorcycle:', sum([i == 2 for i in c_arr]))
# Out:
# Total predictions: 16
# Correct predictions: 11
# Exceptions: 5
# Bicycles: 7
# Motorcycle: 4

# %%
bicycle_inference_res_arr = []
Motorcycle_inference_res_arr = []
for idx in range(len(y)):
    if [i == 1 for i in c_arr][idx]:
        bicycle_inference_res_arr.append(y[idx])
    if [i == 2 for i in c_arr][idx]:
        Motorcycle_inference_res_arr.append(y[idx])

# %%
from matplotlib.pyplot import figure

figure(figsize=(12, 6), dpi=80)

plt.subplot(1,2,1)
plt.title("Bicycle Inference Res", size=14)
plt.boxplot(bicycle_inference_res_arr)

plt.subplot(1,2,2)
plt.title("Motorcycle Inference Res", size=14)
plt.boxplot(Motorcycle_inference_res_arr)
plt.show()

# %%
labels = ['bicycle', 'motorcycle']

# %%
json_data[0]
# Out:
# {'captureData': {'endpointInput': {'observedContentType': 'image/png',
#    'mode': 'INPUT',
#    'data': '...',
#    'encoding': 'BASE64'},
#   'endpointOutput': {'observedContentType': 'application/json',
#    'mode': 'OUTPUT',
#    'data': '[0.0001782575127435848, 0.9998217225074768]',
#    'encoding': 'JSON'}},
#  'eventMetadata': {'eventId': 'd0bdfba1-72d5-4444-93c9-42410226ec98',
#   'inferenceTime': '2022-03-09T20:26:00Z'},
#  'eventVersion': '0'}

# %%
def read_base64_img(data):
    return  mpimg.imread(io.BytesIO(base64.b64decode(data['captureData']['endpointInput']['data'])),format='JPG')

# %%
labels = ['bicycle', 'motorcycle']

columns = len(json_data)
rows = 1
fig = plt.figure(figsize=(20,20))
for i, inference_object in enumerate(json_data):
    # sub img position
    fig.add_subplot(rows, columns, i+1)
    
    image = read_base64_img(inference_object)
    inference_time = inference_object['eventMetadata']['inferenceTime'].split('T')[0]
    inference = json.loads(inference_object['captureData']['endpointOutput']['data'])
    
    plt.imshow(image, interpolation='nearest')
    plt.title(f" probabilities: {str(np.round(inference,3))}\n label: {labels[np.argmax(inference)]}\n inference time: {inference_time}")
#plt.savefig(path.join(figures_dir, "visualization_predicted_images.pdf"), bbox_inches = 'tight')
plt.show()

# %% [markdown]
# ### Congratulations!
#
# You've reached the end of the project. In this project you created an event-drivent ML workflow that can be incorporated into the Scones Unlimited production architecture. You used the SageMaker Estimator API to deploy your SageMaker Model and Endpoint, and you used AWS Lambda and Step Functions to orchestrate your ML workflow. Using SageMaker Model Monitor, you instrumented and observed your Endpoint, and at the end of the project you built a visualization to help stakeholders understand the performance of the Endpoint over time. If you're up for it, you can even go further with these stretch goals:
#
# * Extend your workflow to incorporate more classes: the CIFAR dataset includes other vehicles that Scones Unlimited can identify with this model.
# * Modify your event driven workflow: can you rewrite your Lambda functions so that the workflow can process multiple image inputs in parallel? Can the Step Function "fan out" to accomodate this new workflow?
# * Consider the test data generator we provided for you. Can we use it to create a "dummy data" generator, to simulate a continuous stream of input data? Or a big paralell load of data?
# * What if we want to get notified every time our step function errors out? Can we use the Step Functions visual editor in conjunction with a service like SNS to accomplish this? Try it out!
